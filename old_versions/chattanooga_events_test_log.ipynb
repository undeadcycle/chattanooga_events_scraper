# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# Configuration for a single site (for example: "Visit Chattanooga")
SITE = {
    "name": "CHA Guide Events",
    "url": "https://www.cha.guide/events"
}

def fetch_page(url):
    options = Options()
    options.add_argument("--headless")  # Run in headless mode (no GUI)
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)
    
    try:
        driver.get(url)
        time.sleep(5)  # Wait for JavaScript to load content
        return driver.page_source
    except Exception as e:
        print(f"Error fetching the page: {e}")
        return None
    finally:
        driver.quit()

def parse_html(html_content):
    return BeautifulSoup(html_content, 'html.parser')

def log_parsed_html(parsed_content, site_name):
    with open(f"{site_name}_parsed_log.html", "w", encoding='utf-8') as file:
        file.write(str(parsed_content))

def main():
    site_name = SITE["name"]
    url = SITE["url"]
    
    print(f"Fetching and parsing {site_name}")
    html_content = fetch_page(url)  # This should be using Selenium
    if html_content:
        parsed_content = parse_html(html_content)
        print(f"Length of parsed content: {len(str(parsed_content))}")
        log_parsed_html(parsed_content, site_name)
        print(f"Parsed HTML content has been logged to {site_name}_parsed_log.html")
    else:
        print(f"Skipping {site_name} due to fetch error")

if __name__ == "__main__":
    main()
# Out:
# Fetching and parsing CHA Guide Events
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 52
#      49         print(f"Skipping {site_name} due to fetch error")
#      51 if __name__ == "__main__":
# ---> 52     main()
#
# Cell In[2], line 42, in main()
#      39 url = SITE["url"]
#      41 print(f"Fetching and parsing {site_name}")
# ---> 42 html_content = fetch_page(url)  # This should be using Selenium
#      43 if html_content:
#      44     parsed_content = parse_html(html_content)
#
# Cell In[2], line 18, in fetch_page(url)
#      16 options.add_argument("--headless")  # Run in headless mode (no GUI)
#      17 service = Service(ChromeDriverManager().install())
# ---> 18 driver = webdriver.Chrome(service=service, options=options)
#      20 try:
#      21     driver.get(url)
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/chrome/webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/chromium/webdriver.py:55, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      52     options.browser_version = None
#      54 self.service.path = finder.get_driver_path()
# ---> 55 self.service.start()
#      57 executor = ChromiumRemoteConnection(
#      58     remote_server_addr=self.service.service_url,
#      59     browser_name=browser_name,
#    (...)
#      62     ignore_proxy=options._ignore_local_proxy,
#      63 )
#      65 try:
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/service.py:98, in Service.start(self)
#      91 def start(self) -> None:
#      92     """Starts the Service.
#      93
#      94     :Exceptions:
#      95      - WebDriverException : Raised either when it can't start the service
#      96        or when it can't connect to the service
#      97     """
# ---> 98     self._start_process(self._path)
#     100     count = 0
#     101     while True:
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/service.py:208, in Service._start_process(self, path)
#     205         start_info.dwFlags = subprocess.CREATE_NEW_CONSOLE | subprocess.STARTF_USESHOWWINDOW
#     206         start_info.wShowWindow = subprocess.SW_HIDE
# --> 208     self.process = subprocess.Popen(
#     209         cmd,
#     210         env=self.env,
#     211         close_fds=close_file_descriptors,
#     212         stdout=self.log_output,
#     213         stderr=self.log_output,
#     214         stdin=PIPE,
#     215         creationflags=self.creation_flags,
#     216         startupinfo=start_info,
#     217         **self.popen_kw,
#     218     )
#     219     logger.debug(
#     220         "Started executable: `%s` in a child process with pid: %s using %s to output %s",
#     221         self._path,
#    (...)
#     224         self.log_output,
#     225     )
#     226 except TypeError:
#
# File ~/anaconda3/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/anaconda3/lib/python3.11/subprocess.py:1950, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1948     if errno_num != 0:
#    1949         err_msg = os.strerror(errno_num)
# -> 1950     raise child_exception_type(errno_num, err_msg, err_filename)
#    1951 raise child_exception_type(err_msg)
#
# OSError: [Errno 8] Exec format error: '/home/garner/.wdm/drivers/chromedriver/linux64/127.0.6533.88/chromedriver-linux64/THIRD_PARTY_NOTICES.chromedriver'

# %%
pip install chromedriver-autoinstaller
# Out:
# Collecting chromedriver-autoinstaller
#   Downloading chromedriver_autoinstaller-0.6.4-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: packaging>=23.1 in /home/garner/anaconda3/lib/python3.11/site-packages (from chromedriver-autoinstaller) (23.2)
# Downloading chromedriver_autoinstaller-0.6.4-py3-none-any.whl (7.6 kB)
# Installing collected packages: chromedriver-autoinstaller
# Successfully installed chromedriver-autoinstaller-0.6.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import chromedriver_autoinstaller
from bs4 import BeautifulSoup
from datetime import datetime
import time

# Configuration
SITES = {

    "Visit Chattanooga": {
        "url": "https://www.visitchattanooga.com/events/",
        "content_list_class": {"div": "content grid"},
        "item_attr": {"div": {"data-type": "events"}},
        "title": {"a": {"class": "title truncate"}},
        "date": {"span": {"class": "mini-date-container"}},
        "month": {"span": {"class": "month"}},
        "day": {"span": {"class": "day"}},
        "img": {
            "img": {"class": "thumb"},
            "parse_method": "lazy-src"
        },
        "location": {"li": {"class": "locations truncate"}},
        "recurrence": {"li": {"class": "recurrence"}}
    },
    # "Nooga Today": {
    #     "url": "https://noogatoday.6amcity.com/events#/", # preloaded_lightbox blocking site
    #     "content_list_class": "",
    #     "item_attr": {},
    #     "title_tag": "a",
    #     "title_class": "",
    #     "date_class": "",
    #     "month_class": "",
    #     "day_class": "",
    #     "img_class": "",
    #     "location_class": "",
    #     "recurrence_class": ""
    # },
    # "Choose Chatt": {
    #     "url": "https://choosechatt.com/chattanooga-events/", # dialog-lightbox-message blocking site
    #     "content_list_class": "",
    #     "item_attr": {},
    #     "title_tag": "a",
    #     "title_class": "",
    #     "date_class": "",
    #     "month_class": "",
    #     "day_class": "",
    #     "img_class": "",
    #     "location_class": "",
    #     "recurrence_class": ""
    # },
    "CHA Guide Events": {
        "url": "https://www.cha.guide/events",
        "content_list_class": {"div": "flex-table w-dyn-items"},
        "item_attr": {"div": {"role": "listitem"}},
        "title": {"h3": {"class": "event-title"}},
        "date": {"div": {"class": "event-date-div"}},
        "month": {"div": {"class": "event-month"}},
        "day": {"div": {"class": "event-card-date"}},
        "img": {
            "parse_method": "none",
        },
        "location": {"div": {"class": "location-2"}},
        "recurrence": {"div": {"class": "event---category-circle"}}
        # "category": {"div": {"class": "event---category-circle"}}
        # "details": {"div": {"class": "smaller-text bottom-margin---5px"}}
    },
    "Chattanooga Pulse": {
        "url": "https://www.chattanoogapulse.com/search/event/the-pulse-event-search/#page=1",
        "content_list_class": {"div": {"id": "event_list_div", "class": "results"}},
        "item_attr": {"div": {"class": "event_result"}},
        "title": {"h4": {"class": "event_title"}},
        "date": {"p": {"class": "event_date"}},
        # modify our SITES dictionary to allow for more detailed date extraction instructions per site
        "month_class": "",
        "day_class": "",
        "img": {
            "container": {"div": {"class": "event_thumb"}},
            "tag": "img",
            "attr": "srcset",
            "parse_method": "srcset_220w"
        },
        "location": {"a": {}},
        "recurrence": {"p": {"class": "cats"}}
        # Add a description or details section

    },
    
    # "Times Free Press": {
    #     "url": "https://www.timesfreepress.com/tfpevents/?_evDiscoveryPath=/",
    #     "content_list_class": "",
    #     "item_attr": {},
    #     "title_tag": "a",
    #     "title_class": "",
    #     "date_class": "",
    #     "month_class": "",
    #     "day_class": "",
    #     "img_class": "",
    #     "location_class": "",
    #     "recurrence_class": ""
    # },
    # "CHA Guide Weekly": {
    #     "url": "https://www.cha.guide/explore/things-to-do-in-chattanooga-this-week",
    #     "content_list_class": "",
    #     "item_attr": {},
    #     "title_tag": "a",
    #     "title_class": "",
    #     "date_class": "",
    #     "month_class": "",
    #     "day_class": "",
    #     "img_class": "",
    #     "location_class": "",
    #     "recurrence_class": ""
    # },
    # "Chattanooga Chamber": {
    #     "url": "https://chattanoogachamber.com/",
    #     "content_list_class": "",
    #     "item_attr": {},
    #     "title_tag": "a",
    #     "title_class": "",
    #     "date_class": "",
    #     "month_class": "",
    #     "day_class": "",
    #     "img_class": "",
    #     "location_class": "",
    #     "recurrence_class": ""
    # },
    # "Chattanooga Library": {
    #     "url": "https://www.chattlibrary.org/events/",
    #     "content_list_class": "",
    #     "item_attr": {},
    #     "title_tag": "a",
    #     "title_class": "",
    #     "date_class": "",
    #     "month_class": "",
    #     "day_class": "",
    #     "img_class": "",
    #     "location_class": "",
    #     "recurrence_class": ""
    # }
}

def fetch_page(url):
    options = Options()
    options.add_argument("--headless")  # Run in headless mode (no GUI)
    service = Service(ChromeDriverManager().install())
    chromedriver_autoinstaller.install()
    driver = webdriver.Chrome()
    
    try:
        driver.get(url)
        time.sleep(5)  # Wait for JavaScript to load content
        return driver.page_source
    except Exception as e:
        print(f"Error fetching the page: {e}")
        return None
    finally:
        driver.quit()

def parse_html(html_content):
    return BeautifulSoup(html_content, 'html.parser')

def extract_image_url(img_config, item):
    if img_config['parse_method'] == 'lazy-src':
        img_tag, img_attrs = next(iter(img_config.items()))
        img_element = item.find(img_tag, **img_attrs)
        return img_element.get('data-lazy-src') or img_element.get('src') if img_element else None

    elif img_config['parse_method'] == 'srcset_220w':
        container_tag, container_attrs = next(iter(img_config['container'].items()))
        container = item.find(container_tag, **container_attrs)
        if not container:
            return None

        img_element = container.find(img_config['tag'])
        if not img_element or img_config['attr'] not in img_element.attrs:
            return None

        srcset = img_element[img_config['attr']]
        urls = srcset.split(', ')
        for url in urls:
            if '220w' in url:
                return url.split(' ')[0]
        return urls[0].split(' ')[0] if urls else None

    elif img_config['parse_method'] == 'none':
        return None
    
    # Add other parsing methods here if needed
    
    return None

def extract_events(parsed_content, config):
    events = []
    print(f"Searching for content list with: {config['content_list_class']}")
    
    # Unpack the content_list_class dictionary
    tag, class_name = next(iter(config['content_list_class'].items()))
    content_list = parsed_content.find(tag, class_=class_name)
    
    if not content_list:
        print("Couldn't find content list")
        return events

    # Unpack the item_attr dictionary
    item_tag, item_attrs = next(iter(config['item_attr'].items()))
    items = content_list.find_all(item_tag, **item_attrs)
    
    print(f"Found {len(items)} items with specified attributes")
    
    for item in items:
        event = {}
        
        # Extract title and URL
        title_tag, title_attrs = next(iter(config['title'].items()))
        title_element = item.find(title_tag, **title_attrs)
        if title_element:
            event['title'] = title_element.text.strip()
            url_element = title_element if title_element.name == 'a' else title_element.find_parent('a')
            event['url'] = config["url"] + url_element['href'] if url_element else ''
        else:
            print("Couldn't find title element")
            continue
        
        # Extract date
        date_tag, date_attrs = next(iter(config['date'].items()))
        date_element = item.find(date_tag, **date_attrs)
        if date_element:
            month_tag, month_attrs = next(iter(config['month'].items()))
            day_tag, day_attrs = next(iter(config['day'].items()))
            month = date_element.find(month_tag, **month_attrs)
            day = date_element.find(day_tag, **day_attrs)
            if month and day:
                event_date = f"{month.text.strip()} {day.text.strip()}, {datetime.now().year}"
                event['date'] = event_date
            else:
                event['date'] = date_element.text.strip()
        else:
            event['date'] = None
        
        # Extract image URL
        if config.get("img"):
            event['image_url'] = extract_image_url(config["img"], item)
        else:
            event['image_url'] = None
        
        # Extract location
        location_tag, location_attrs = next(iter(config['location'].items()))
        location_element = item.find(location_tag, **location_attrs)
        event['location'] = location_element.text.strip() if location_element else None
        
        # Extract recurrence information
        recurrence_tag, recurrence_attrs = next(iter(config['recurrence'].items()))
        recurrence_element = item.find(recurrence_tag, **recurrence_attrs)
        event['recurrence'] = recurrence_element.text.strip() if recurrence_element else None
        
        events.append(event)
    
    return events

def main():
    for site_name, config in SITES.items():
        url = config["url"]
        print(f"Fetching and parsing {site_name}")
        html_content = fetch_page(url)  # This should be using Selenium
        if html_content:
            parsed_content = parse_html(html_content)
            print(f"Length of parsed content: {len(str(parsed_content))}")
            events = extract_events(parsed_content, config)
            print(f"Extracted {len(events)} events")
            for event in events:
                print(f"Title: {event.get('title')}")
                print(f"URL: {event.get('url')}")
                print(f"Date: {event.get('date')}")
                print(f"Image URL: {event.get('image_url')}")
                print(f"Location: {event.get('location')}")
                print(f"Recurrence: {event.get('recurrence')}")
                print("-" * 40)
        else:
            print(f"Skipping {site_name} due to fetch error")
        time.sleep(1)  # Be polite, wait a second between requests

if __name__ == "__main__":
    main()
# Out:
# Fetching and parsing Visit Chattanooga
# Length of parsed content: 502334
# Searching for content list with: {'div': 'content grid'}
# Found 12 items with specified attributes
# Extracted 12 events
# Title: Chickamauga Dam Lock Through Kayak Tour with Chattanooga Guided Adventures
# URL: https://www.visitchattanooga.com/events//event/chickamauga-dam-lock-through-kayak-tour-with-chattanooga-guided-adventures/19807/
# Date: Aug 05, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/CGA-Chickamanga_17047717-561C-4434-B479C10F432C4937_42bd9946-ca66-4b83-9259ff2418b75f33.jpg
# Location: Hubert Fry Center Boatramp
# Recurrence: Recurring daily until November 10, 2024
# ----------------------------------------
# Title: Deadpool & Wolverine in IMAX!
# URL: https://www.visitchattanooga.com/events//event/deadpool-%26-wolverine-in-imax!/20885/
# Date: Aug 05, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/SUB6400_comp_FRM_v0220.1387_R_228096AB-B639-4512-975312EDA16B40DF_08a685ff-4a2f-45c9-bf452d06e775dbdf.jpg
# Location: Tennessee Aquarium IMAX 3D Theater
# Recurrence: None
# ----------------------------------------
# Title: Exhibit Admission
# URL: https://www.visitchattanooga.com/events//event/exhibit-admission/17763/
# Date: Aug 05, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Tennessee-Valley-Railroad-Museum-Exhibit-Building-03-scaled_4F4495E7-023E-49F5-89D214567AE32153_fc60f811-20ec-4b1f-80574d7f0d0d1c4a.jpg
# Location: Tennessee Valley Railroad Museum
# Recurrence: Recurring daily until December 23, 2024
# ----------------------------------------
# Title: Mountain Bike Rental with Chattanooga Guided Adventures
# URL: https://www.visitchattanooga.com/events//event/mountain-bike-rental-with-chattanooga-guided-adventures/19809/
# Date: Aug 05, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Incline-Railway-Bike-Tour_E81C8BF8-A9AE-4386-99A3AE8E86E6EFF0_8c1b23e6-485b-4296-9d4b5d7719fd0143.jpg
# Location: Chattanooga Guided Adventures
# Recurrence: Recurring daily until January 21, 2025
# ----------------------------------------
# Title: Nickajack Bat Cave Kayak Tour with Chattanooga Guided Adventures
# URL: https://www.visitchattanooga.com/events//event/nickajack-bat-cave-kayak-tour-with-chattanooga-guided-adventures/19747/
# Date: Aug 05, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Nickajack-Bat-Cave-Sunset-Kayak-Tour_6F28E129-02C9-4D96-A9031235E67BFB56_4fca779d-b1b8-4613-9d4c7a0faa9487a5.jpg
# Location: Chattanooga Guided Adventures
# Recurrence: Recurring daily until October 13, 2024
# ----------------------------------------
# Title: Pizza on the Patio with The Chattanooga Girls Choir
# URL: https://www.visitchattanooga.com/events//event/pizza-on-the-patio-with-the-chattanooga-girls-choir/21191/
# Date: Aug 05, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/PIzza-on-the-Patio_9BD5031E-EC2B-9CF2-6B2C49CD755F1596_9bd8f83d-c377-408b-3f5c93b1e1820389.png
# Location: 650 McCallie Ave, Chattanooga TN 37403
# Recurrence: None
# ----------------------------------------
# Title: Ruby Falls History Exhibit: Celebrating 95 Years of Wonder!
# URL: https://www.visitchattanooga.com/events//event/ruby-falls-history-exhibit%3a-celebrating-95-years-of-wonder!/20838/
# Date: Aug 05, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/exhibit_67559FE5-978B-483E-8D00CCB039CDF985_42d2cd7d-a013-4fa8-9169c14e67bb5dcb.jpg
# Location: Ruby Falls
# Recurrence: Recurring daily until October 20, 2024
# ----------------------------------------
# Title: "Home and Away"
# URL: https://www.visitchattanooga.com/events//event/home-and-away/21247/
# Date: Aug 05, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Chattanooga-collage-copy_3A4D3FC1-A17E-974B-6BF212B8FF3C24B0_3a55b2a8-c680-313c-36860ca4ad8df2c3.jpg
# Location: In-Town Gallery
# Recurrence: Recurring daily until August 31, 2024
# ----------------------------------------
# Title: History Tour - New Cave Adventure!
# URL: https://www.visitchattanooga.com/events//event/history-tour-new-cave-adventure!/20729/
# Date: Aug 05, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/History-Tour_03F38BD5-B899-4F31-B99475A7612C4AB1_ce536786-a5b0-44cc-85359e8800fa2601.jpg
# Location: Ruby Falls
# Recurrence: None
# ----------------------------------------
# Title: Live Music every Tuesday & Saturday at Honey Seed
# URL: https://www.visitchattanooga.com/events//event/live-music-every-tuesday-%26-saturday-at-honey-seed/20185/
# Date: Aug 06, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/honey-seed-exterior_CE982A8C-E97E-161D-6083B678CC18FA38_ce9a56a4-f41a-b43c-1cf05085385a5eff.jpg
# Location: Honey Seed
# Recurrence: Recurring weekly on Tuesday, Saturday until February 25, 2025
# ----------------------------------------
# Title: Chattanooga Red Wolves SC vs. Spokane Velocity FC
# URL: https://www.visitchattanooga.com/events//event/chattanooga-red-wolves-sc-vs-spokane-velocity-fc/20336/
# Date: Aug 07, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Chattanooga-Red-Wolves-Logo_D1F839F3-FE1F-06AA-69CFD4CB9CAD822C_d20bc4ef-a3ee-dfb2-639a4aa0b05292b4.jpg
# Location: CHI Memorial Stadium
# Recurrence: None
# ----------------------------------------
# Title: Tennessee Senior Olympics Pickleball State Championship
# URL: https://www.visitchattanooga.com/events//event/tennessee-senior-olympics-pickleball-state-championship/20924/
# Date: Aug 07, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Senior-Olympics-Logo_1F4B129D-CCB7-E02E-1F6207CCD2C903CC_1f89e8f2-f66d-d49c-2d194877b980f990.jpg
# Location: Chattanooga Convention Center
# Recurrence: Recurring daily until August 11, 2024
# ----------------------------------------
# Fetching and parsing CHA Guide Events
# Length of parsed content: 364729
# Searching for content list with: {'div': 'flex-table w-dyn-items'}
# Found 78 items with specified attributes
# Extracted 78 events
# Title: Black Professionals @ The Hunter
# URL: https://www.cha.guide/events/events/black-professionals-the-hunter
# Date: Aug 5, 2024
# Image URL: None
# Location: Hunter Museum of American Art
# Recurrence:
# ----------------------------------------
# Title: Franchise Tax Cut Lunch and Learn
# URL: https://www.cha.guide/events/events/franchise-tax-cut-lunch-and-learn
# Date: Aug 5, 2024
# Image URL: None
# Location: Chattanooga Area Chamber of Commerce
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-44
# Date: Aug 7, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: AM Networking
# URL: https://www.cha.guide/events/events/am-networking
# Date: Aug 7, 2024
# Image URL: None
# Location: 2265 Gunbarrel Rd
# Recurrence:
# ----------------------------------------
# Title: Free Family Night @ Creative Discovery Museum
# URL: https://www.cha.guide/events/events/free-family-night-creative-discovery-museum-4
# Date: Aug 8, 2024
# Image URL: None
# Location: Creative Discovery Museum
# Recurrence:
# ----------------------------------------
# Title: Open Mic Night (Summer Series!) @ Songbirds
# URL: https://www.cha.guide/events/events/open-mic-night-summer-series-songbirds-2
# Date: Aug 8, 2024
# Image URL: None
# Location: Songbirds
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-12
# Date: Aug 9, 2024
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-18
# Date: Aug 9, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-40
# Date: Aug 10, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-17
# Date: Aug 10, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-12
# Date: Aug 10, 2024
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-19
# Date: Aug 10, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-45
# Date: Aug 14, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Art Deco And Dance With Ballet Esprit
# URL: https://www.cha.guide/events/events/art-deco-and-dance-with-ballet-esprit
# Date: Aug 15, 2024
# Image URL: None
# Location: Hunter Museum of American Art
# Recurrence:
# ----------------------------------------
# Title: Business After Hours | Big Chicken
# URL: https://www.cha.guide/events/events/business-after-hours-big-chicken
# Date: Aug 15, 2024
# Image URL: None
# Location: Big Chicken
# Recurrence:
# ----------------------------------------
# Title: The Concert: A Tribute To ABBA
# URL: https://www.cha.guide/events/events/the-concert-a-tribute-to-abba
# Date: Aug 16, 2024
# Image URL: None
# Location: Walker Theatre
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-13
# Date: Aug 16, 2024
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-20
# Date: Aug 16, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-41
# Date: Aug 17, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-18
# Date: Aug 17, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Jamey Johnson @ Soldiers and Sailors Memorial Auditorium
# URL: https://www.cha.guide/events/events/jamey-johnson-soldiers-and-sailors-memorial-auditorium
# Date: Aug 17, 2024
# Image URL: None
# Location: Soldiers and Sailors Memorial Auditorium
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-14
# Date: Aug 17, 2024
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-21
# Date: Aug 17, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Artful Yoga
# URL: https://www.cha.guide/events/events/artful-yoga
# Date: Aug 18, 2024
# Image URL: None
# Location: Hunter Museum of American Art
# Recurrence:
# ----------------------------------------
# Title: Tennessee Harp Trio Community Concert
# URL: https://www.cha.guide/events/events/tennessee-harp-trio-community-concert
# Date: Aug 18, 2024
# Image URL: None
# Location: Skyline Loft at Ruby Falls
# Recurrence:
# ----------------------------------------
# Title: Night Ranger @ Walker Theatre
# URL: https://www.cha.guide/events/events/chris-delia-walker-theatre
# Date: Aug 20, 2024
# Image URL: None
# Location: Walker Theatre
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-46
# Date: Aug 21, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-14
# Date: Aug 23, 2024
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-22
# Date: Aug 23, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-42
# Date: Aug 24, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-19
# Date: Aug 24, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-13
# Date: Aug 24, 2024
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-23
# Date: Aug 24, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Nate Jackson @ Walker Theatre
# URL: https://www.cha.guide/events/events/nate-jackson-walker-theatre
# Date: Aug 24, 2024
# Image URL: None
# Location: Walker Theatre
# Recurrence:
# ----------------------------------------
# Title: Chocolate Festival
# URL: https://www.cha.guide/events/events/chocolate-festival
# Date: Aug 24, 2024
# Image URL: None
# Location: Creative Discovery Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-47
# Date: Aug 28, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-15
# Date: Aug 30, 2024
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-24
# Date: Aug 30, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-43
# Date: Aug 31, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-20
# Date: Aug 31, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-15
# Date: Aug 31, 2024
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-25
# Date: Aug 31, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Labor Day Brunch at Whitebird/The Edwin Hotel
# URL: https://www.cha.guide/events/events/labor-day-brunch-at-whitebird-the-edwin-hotel
# Date: Sep 2, 2024
# Image URL: None
# Location: Whitebird
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-48
# Date: Sep 4, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Candlelight: Tribute to Beyoncé
# URL: https://www.cha.guide/events/events/candlelight-tribute-to-beyonce
# Date: Sep 5, 2024
# Image URL: None
# Location: The Beverly Ballroom at Hotel Chalet
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-44
# Date: Sep 7, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-21
# Date: Sep 7, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-26
# Date: Sep 7, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-49
# Date: Sep 11, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-45
# Date: Sep 14, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-50
# Date: Sep 18, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-46
# Date: Sep 21, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-22
# Date: Sep 21, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: 2024 CBD Plus Cannabis Music Festival
# URL: https://www.cha.guide/events/events/2024-cbd-plus-cannabis-music-festival
# Date: Sep 21, 2024
# Image URL: None
# Location: Coolidge Park
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-23
# Date: Sep 22, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-51
# Date: Sep 25, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Intermission - A celebration of the arts in Chattanooga
# URL: https://www.cha.guide/events/events/intermission-a-celebration-of-the-arts-in-chattanooga
# Date: Sep 25, 2024
# Image URL: None
# Location: Chattanooga Theater Center
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-24
# Date: Sep 27, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-47
# Date: Sep 28, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: KIC Food Truck Festival & Expo
# URL: https://www.cha.guide/events/events/kic-food-truck-festival-expo
# Date: Sep 28, 2024
# Image URL: None
# Location: Kitchen Incubator of Chattanooga
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-52
# Date: Oct 2, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: OVO – a buzzing Cirque du Soleil spectacular
# URL: https://www.cha.guide/events/events/ovo-a-buzzing-cirque-du-soleil-spectacular
# Date: Oct 3, 2024
# Image URL: None
# Location: McKenzie Arena
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-48
# Date: Oct 5, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-53
# Date: Oct 9, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-54
# Date: Oct 16, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-49
# Date: Oct 19, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-55
# Date: Oct 23, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Candlelight: A Haunted Evening of Halloween Classics
# URL: https://www.cha.guide/events/events/candlelight-a-haunted-evening-of-halloween-classics
# Date: Oct 24, 2024
# Image URL: None
# Location: The Beverly Ballroom at Hotel Chalet
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-50
# Date: Oct 26, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-56
# Date: Oct 30, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-57
# Date: Nov 6, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-58
# Date: Nov 13, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Date Night at Frothy Monkey
# URL: https://www.cha.guide/events/events/date-night-at-frothy-monkey-2
# Date: Nov 14, 2024
# Image URL: None
# Location: Frothy Monkey
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-59
# Date: Nov 20, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-60
# Date: Dec 4, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-61
# Date: Dec 11, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-62
# Date: Dec 18, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: WHITECHAPEL "TENNESSEE TAKEOVER 2024"
# URL: https://www.cha.guide/events/events/whitechapel-tennessee-takeover-2024
# Date: Dec 19, 2024
# Image URL: None
# Location: The Signal
# Recurrence:
# ----------------------------------------
# Fetching and parsing Chattanooga Pulse
# Length of parsed content: 94110
# Searching for content list with: {'div': {'id': 'event_list_div', 'class': 'results'}}
# Couldn't find content list
# Extracted 0 events

# %% [markdown]
# # Latest working code:

# %%
from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import chromedriver_autoinstaller
from bs4 import BeautifulSoup
from datetime import datetime
from dateutil import parser
import time
import re

# Configuration
SITES = {

    "Visit Chattanooga": {
        "url": "https://www.visitchattanooga.com/events/",
        "content_list_class": {"div": {"class": "content grid"}},
        "item_attr": {"div": {"data-type": "events"}},
        "title": {"a": {"class": "title truncate"}},
        "date": {"span": {"class": "mini-date-container"}},
        "img": {
            "img": {"class": "thumb"},
            "parse_method": "lazy-src"
        },
        "location": {"li": {"class": "locations truncate"}},
        "recurrence": {"li": {"class": "recurrence"}}
    },

    "CHA Guide Events": {
        "url": "https://www.cha.guide/events",
        "content_list_class": {"div": {"class": "flex-table w-dyn-items"}},
        "item_attr": {"div": {"role": "listitem"}},
        "title": {"h3": {"class": "event-title"}},
        "date": {"div": {"class": "event-date-div"}},
        "img": {
            "parse_method": "none",
        },
        "location": {"div": {"class": "location-2"}},
        "recurrence": {"div": {"class": "event---category-circle"}}
        # "category": {"div": {"class": "event---category-circle"}}
        # "details": {"div": {"class": "smaller-text bottom-margin---5px"}}
    },
    
    "Chattanooga Pulse": {
        "url": "https://www.chattanoogapulse.com/search/event/the-pulse-event-search/#page=1",
        "content_list_class": {"div": {"id": "event_list_div"}},
        "item_attr": {"div": {"class": "event_result"}},
        "title": {"h4": {"class": "event_title"}},
        "date": {"p": {"class": "event_date"}},
        "img": {
            "container": {"div": {"class": "event_thumb"}},
            "tag": "img",
            "attr": "srcset",
            "parse_method": "srcset_220w"
        },
        "location": {"a": {}}, # outputs title instead of location
        "recurrence": {"p": {"class": "cats"}}
        # Add a description or details section

    },
    
    # "Nooga Today": {
    #     "url": "https://noogatoday.6amcity.com/events#/", # preloaded_lightbox blocking site
    #     },
    
    # "Choose Chatt": {
    #     "url": "https://choosechatt.com/chattanooga-events/", # dialog-lightbox-message blocking site
    # },

    # "Times Free Press": {
    #     "url": "https://www.timesfreepress.com/tfpevents/?_evDiscoveryPath=/",
    # },

    # "CHA Guide Weekly": {
    #     "url": "https://www.cha.guide/explore/things-to-do-in-chattanooga-this-week",
    # },

    # "Chattanooga Chamber": {
    #     "url": "https://chattanoogachamber.com/",
    # },

    # "Chattanooga Library": {
    #     "url": "https://www.chattlibrary.org/events/",
    # }

}

def fetch_page(url):
    options = Options()
    options.add_argument("--headless")  # Run in headless mode (no GUI)
    service = Service(ChromeDriverManager().install())
    chromedriver_autoinstaller.install()
    driver = webdriver.Chrome()
    
    try:
        driver.get(url)
        time.sleep(5)  # Wait for JavaScript to load content
        return driver.page_source
    except Exception as e:
        print(f"Error fetching the page: {e}")
        return None
    finally:
        driver.quit()

def parse_html(html_content):
    return BeautifulSoup(html_content, 'html.parser')

def extract_image_url(img_config, item):
    if img_config['parse_method'] == 'lazy-src':
        img_tag, img_attrs = next(iter(img_config.items()))
        img_element = item.find(img_tag, **img_attrs)
        return img_element.get('data-lazy-src') or img_element.get('src') if img_element else None

    elif img_config['parse_method'] == 'srcset_220w':
        container_tag, container_attrs = next(iter(img_config['container'].items()))
        container = item.find(container_tag, **container_attrs)
        if not container:
            return None

        img_element = container.find(img_config['tag'])
        if not img_element or img_config['attr'] not in img_element.attrs:
            return None

        srcset = img_element[img_config['attr']]
        urls = srcset.split(', ')
        for url in urls:
            if '220w' in url:
                return url.split(' ')[0]
        return urls[0].split(' ')[0] if urls else None

    elif img_config['parse_method'] == 'none':
        return None
    
    # Add other parsing methods here if needed
    
    return None

def parse_date_range(date_text):
    # Regular expression to match date, start time, and end time
    pattern = r'(\w+ \d+, \d{4})(?: (\d+:\d+ [AP]M))?(?: - (\d+:\d+ [AP]M))?'
    match = re.match(pattern, date_text)
    
    if match:
        date_str, start_time, end_time = match.groups()
        
        try:
            # Parse the date
            parsed_date = parser.parse(date_str)
            date = parsed_date.strftime("%Y-%m-%d")
            
            # Parse start time if available
            start = None
            if start_time:
                start = parser.parse(f"{date_str} {start_time}").strftime("%H:%M")
            
            # Parse end time if available
            end = None
            if end_time:
                end = parser.parse(f"{date_str} {end_time}").strftime("%H:%M")
            
            return {
                'date': date,
                'start_time': start,
                'end_time': end
            }
        except ValueError:
            print(f"Couldn't parse date: {date_text}")
    
    return {
        'date': None,
        'start_time': None,
        'end_time': None
    }

def extract_events(parsed_content, config):
    events = []
    print(f"Searching for content list with: {config['content_list_class']}")
    
    # Unpack the content_list_class dictionary
    tag, class_name = next(iter(config['content_list_class'].items()))
    
    content_list = None
    
    # Try to find content list by id first
    try:
        if 'id' in class_name:
            content_list = parsed_content.find(tag, id=class_name['id'])
            print(f"Attempting to find content list by id: {class_name['id']}")
    except Exception as e:
        print(f"Error when searching by id: {e}")

    # If not found by id, try to find by class
    if not content_list:
        try:
            if 'class' in class_name:
                content_list = parsed_content.find(tag, class_=class_name['class'])
                print(f"Attempting to find content list by class: {class_name['class']}")
        except Exception as e:
            print(f"Error when searching by class: {e}")

    # If still not found, try to find without any attributes
    if not content_list:
        try:
            content_list = parsed_content.find(tag)
            print(f"Attempting to find content list by tag: {tag}")
        except Exception as e:
            print(f"Error when searching by tag: {e}")

    if not content_list:
        print("Couldn't find content list")
        return events

    # print(f"Found content list: {content_list}")

    # Unpack the item_attr dictionary
    item_tag, item_attrs = next(iter(config['item_attr'].items()))
    try:
        items = content_list.find_all(item_tag, **item_attrs)
        print(f"Found {len(items)} items with specified attributes")
    except Exception as e:
        print(f"Error when finding items: {e}")
        return events

    for item in items:
        event = {}
        
        # Extract title and URL
        try:
            title_tag, title_attrs = next(iter(config['title'].items()))
            title_element = item.find(title_tag, **title_attrs)
            if title_element:
                event['title'] = title_element.text.strip()
                url_element = title_element if title_element.name == 'a' else title_element.find_parent('a')
                event['url'] = config["url"] + url_element['href'] if url_element else ''
            else:
                print("Couldn't find title element")
                continue
        except Exception as e:
            print(f"Error extracting title: {e}")
            continue

        # Extract date and times
        try:
            date_tag, date_attrs = next(iter(config['date'].items()))
            date_element = item.find(date_tag, **date_attrs)
            if date_element:
                date_text = date_element.text.strip()
                date_info = parse_date_range(date_text)
                event.update(date_info)
            else:
                event.update({
                    'date': None,
                    'start_time': None,
                    'end_time': None
                })
        except Exception as e:
            print(f"Error extracting date: {e}")

        # Extract image URL
        try:
            if config.get("img"):
                event['image_url'] = extract_image_url(config["img"], item)
            else:
                event['image_url'] = None
        except Exception as e:
            print(f"Error extracting image URL: {e}")
            event['image_url'] = None

        # Extract location
        try:
            location_tag, location_attrs = next(iter(config['location'].items()))
            location_element = item.find(location_tag, **location_attrs)
            event['location'] = location_element.text.strip() if location_element else None
        except Exception as e:
            print(f"Error extracting location: {e}")
            event['location'] = None

        # Extract recurrence information
        try:
            recurrence_tag, recurrence_attrs = next(iter(config['recurrence'].items()))
            recurrence_element = item.find(recurrence_tag, **recurrence_attrs)
            event['recurrence'] = recurrence_element.text.strip() if recurrence_element else None
        except Exception as e:
            print(f"Error extracting recurrence: {e}")
            event['recurrence'] = None

        events.append(event)
    
    return events

def main():
    for site_name, config in SITES.items():
        url = config["url"]
        print(f"Fetching and parsing {site_name}")
        html_content = fetch_page(url)
        if html_content:
            parsed_content = parse_html(html_content)
            print(f"Length of parsed content: {len(str(parsed_content))}")
            events = extract_events(parsed_content, config)
            print(f"Extracted {len(events)} events")
            for event in events:
                print(f"Title: {event.get('title')}")
                print(f"URL: {event.get('url')}")
                print(f"Date: {event.get('date')}")
                print(f"Start Time: {event.get('start_time')}")
                print(f"End Time: {event.get('end_time')}")
                print(f"Image URL: {event.get('image_url')}")
                print(f"Location: {event.get('location')}")
                print(f"Recurrence: {event.get('recurrence')}")
                print("-" * 40)
        else:
            print(f"Skipping {site_name} due to fetch error")
        time.sleep(1)  # Be polite, wait a second between requests

if __name__ == "__main__":
    main()
# Out:
# Fetching and parsing Visit Chattanooga
# Length of parsed content: 502460
# Searching for content list with: {'div': {'class': 'content grid'}}
# Attempting to find content list by class: content grid
# Found 12 items with specified attributes
# Extracted 12 events
# Title: Chickamauga Dam Lock Through Kayak Tour with Chattanooga Guided Adventures
# URL: https://www.visitchattanooga.com/events//event/chickamauga-dam-lock-through-kayak-tour-with-chattanooga-guided-adventures/19807/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/CGA-Chickamanga_17047717-561C-4434-B479C10F432C4937_42bd9946-ca66-4b83-9259ff2418b75f33.jpg
# Location: Hubert Fry Center Boatramp
# Recurrence: Recurring daily until November 10, 2024
# ----------------------------------------
# Title: Deadpool & Wolverine in IMAX!
# URL: https://www.visitchattanooga.com/events//event/deadpool-%26-wolverine-in-imax!/20885/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/SUB6400_comp_FRM_v0220.1387_R_228096AB-B639-4512-975312EDA16B40DF_08a685ff-4a2f-45c9-bf452d06e775dbdf.jpg
# Location: Tennessee Aquarium IMAX 3D Theater
# Recurrence: None
# ----------------------------------------
# Title: Exhibit Admission
# URL: https://www.visitchattanooga.com/events//event/exhibit-admission/17763/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Tennessee-Valley-Railroad-Museum-Exhibit-Building-03-scaled_4F4495E7-023E-49F5-89D214567AE32153_fc60f811-20ec-4b1f-80574d7f0d0d1c4a.jpg
# Location: Tennessee Valley Railroad Museum
# Recurrence: Recurring daily until December 23, 2024
# ----------------------------------------
# Title: Mountain Bike Rental with Chattanooga Guided Adventures
# URL: https://www.visitchattanooga.com/events//event/mountain-bike-rental-with-chattanooga-guided-adventures/19809/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Incline-Railway-Bike-Tour_E81C8BF8-A9AE-4386-99A3AE8E86E6EFF0_8c1b23e6-485b-4296-9d4b5d7719fd0143.jpg
# Location: Chattanooga Guided Adventures
# Recurrence: Recurring daily until January 21, 2025
# ----------------------------------------
# Title: Nickajack Bat Cave Kayak Tour with Chattanooga Guided Adventures
# URL: https://www.visitchattanooga.com/events//event/nickajack-bat-cave-kayak-tour-with-chattanooga-guided-adventures/19747/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Nickajack-Bat-Cave-Sunset-Kayak-Tour_6F28E129-02C9-4D96-A9031235E67BFB56_4fca779d-b1b8-4613-9d4c7a0faa9487a5.jpg
# Location: Chattanooga Guided Adventures
# Recurrence: Recurring daily until October 13, 2024
# ----------------------------------------
# Title: Pizza on the Patio with The Chattanooga Girls Choir
# URL: https://www.visitchattanooga.com/events//event/pizza-on-the-patio-with-the-chattanooga-girls-choir/21191/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/PIzza-on-the-Patio_9BD5031E-EC2B-9CF2-6B2C49CD755F1596_9bd8f83d-c377-408b-3f5c93b1e1820389.png
# Location: 650 McCallie Ave, Chattanooga TN 37403
# Recurrence: None
# ----------------------------------------
# Title: Ruby Falls History Exhibit: Celebrating 95 Years of Wonder!
# URL: https://www.visitchattanooga.com/events//event/ruby-falls-history-exhibit%3a-celebrating-95-years-of-wonder!/20838/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/exhibit_67559FE5-978B-483E-8D00CCB039CDF985_42d2cd7d-a013-4fa8-9169c14e67bb5dcb.jpg
# Location: Ruby Falls
# Recurrence: Recurring daily until October 20, 2024
# ----------------------------------------
# Title: "Home and Away"
# URL: https://www.visitchattanooga.com/events//event/home-and-away/21247/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Chattanooga-collage-copy_3A4D3FC1-A17E-974B-6BF212B8FF3C24B0_3a55b2a8-c680-313c-36860ca4ad8df2c3.jpg
# Location: In-Town Gallery
# Recurrence: Recurring daily until August 31, 2024
# ----------------------------------------
# Title: History Tour - New Cave Adventure!
# URL: https://www.visitchattanooga.com/events//event/history-tour-new-cave-adventure!/20729/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/History-Tour_03F38BD5-B899-4F31-B99475A7612C4AB1_ce536786-a5b0-44cc-85359e8800fa2601.jpg
# Location: Ruby Falls
# Recurrence: None
# ----------------------------------------
# Title: Live Music every Tuesday & Saturday at Honey Seed
# URL: https://www.visitchattanooga.com/events//event/live-music-every-tuesday-%26-saturday-at-honey-seed/20185/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/honey-seed-exterior_CE982A8C-E97E-161D-6083B678CC18FA38_ce9a56a4-f41a-b43c-1cf05085385a5eff.jpg
# Location: Honey Seed
# Recurrence: Recurring weekly on Tuesday, Saturday until February 25, 2025
# ----------------------------------------
# Title: Chattanooga Red Wolves SC vs. Spokane Velocity FC
# URL: https://www.visitchattanooga.com/events//event/chattanooga-red-wolves-sc-vs-spokane-velocity-fc/20336/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Chattanooga-Red-Wolves-Logo_D1F839F3-FE1F-06AA-69CFD4CB9CAD822C_d20bc4ef-a3ee-dfb2-639a4aa0b05292b4.jpg
# Location: CHI Memorial Stadium
# Recurrence: None
# ----------------------------------------
# Title: Tennessee Senior Olympics Pickleball State Championship
# URL: https://www.visitchattanooga.com/events//event/tennessee-senior-olympics-pickleball-state-championship/20924/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Senior-Olympics-Logo_1F4B129D-CCB7-E02E-1F6207CCD2C903CC_1f89e8f2-f66d-d49c-2d194877b980f990.jpg
# Location: Chattanooga Convention Center
# Recurrence: Recurring daily until August 11, 2024
# ----------------------------------------
# Fetching and parsing CHA Guide Events
# Length of parsed content: 364668
# Searching for content list with: {'div': {'class': 'flex-table w-dyn-items'}}
# Attempting to find content list by class: flex-table w-dyn-items
# Found 78 items with specified attributes
# Extracted 78 events
# Title: Black Professionals @ The Hunter
# URL: https://www.cha.guide/events/events/black-professionals-the-hunter
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Hunter Museum of American Art
# Recurrence:
# ----------------------------------------
# Title: Franchise Tax Cut Lunch and Learn
# URL: https://www.cha.guide/events/events/franchise-tax-cut-lunch-and-learn
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Chattanooga Area Chamber of Commerce
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-44
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: AM Networking
# URL: https://www.cha.guide/events/events/am-networking
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: 2265 Gunbarrel Rd
# Recurrence:
# ----------------------------------------
# Title: Free Family Night @ Creative Discovery Museum
# URL: https://www.cha.guide/events/events/free-family-night-creative-discovery-museum-4
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Creative Discovery Museum
# Recurrence:
# ----------------------------------------
# Title: Open Mic Night (Summer Series!) @ Songbirds
# URL: https://www.cha.guide/events/events/open-mic-night-summer-series-songbirds-2
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Songbirds
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-12
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-18
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-40
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-17
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-12
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-19
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-45
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Art Deco And Dance With Ballet Esprit
# URL: https://www.cha.guide/events/events/art-deco-and-dance-with-ballet-esprit
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Hunter Museum of American Art
# Recurrence:
# ----------------------------------------
# Title: Business After Hours | Big Chicken
# URL: https://www.cha.guide/events/events/business-after-hours-big-chicken
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Big Chicken
# Recurrence:
# ----------------------------------------
# Title: The Concert: A Tribute To ABBA
# URL: https://www.cha.guide/events/events/the-concert-a-tribute-to-abba
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Walker Theatre
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-13
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-20
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-41
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-18
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Jamey Johnson @ Soldiers and Sailors Memorial Auditorium
# URL: https://www.cha.guide/events/events/jamey-johnson-soldiers-and-sailors-memorial-auditorium
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Soldiers and Sailors Memorial Auditorium
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-14
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-21
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Artful Yoga
# URL: https://www.cha.guide/events/events/artful-yoga
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Hunter Museum of American Art
# Recurrence:
# ----------------------------------------
# Title: Tennessee Harp Trio Community Concert
# URL: https://www.cha.guide/events/events/tennessee-harp-trio-community-concert
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Skyline Loft at Ruby Falls
# Recurrence:
# ----------------------------------------
# Title: Night Ranger @ Walker Theatre
# URL: https://www.cha.guide/events/events/chris-delia-walker-theatre
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Walker Theatre
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-46
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-14
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-22
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-42
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-19
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-13
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-23
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Nate Jackson @ Walker Theatre
# URL: https://www.cha.guide/events/events/nate-jackson-walker-theatre
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Walker Theatre
# Recurrence:
# ----------------------------------------
# Title: Chocolate Festival
# URL: https://www.cha.guide/events/events/chocolate-festival
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Creative Discovery Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-47
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-15
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-24
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-43
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-20
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-15
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-25
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Labor Day Brunch at Whitebird/The Edwin Hotel
# URL: https://www.cha.guide/events/events/labor-day-brunch-at-whitebird-the-edwin-hotel
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Whitebird
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-48
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Candlelight: Tribute to Beyoncé
# URL: https://www.cha.guide/events/events/candlelight-tribute-to-beyonce
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: The Beverly Ballroom at Hotel Chalet
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-44
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-21
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-26
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-49
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-45
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-50
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-46
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-22
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: 2024 CBD Plus Cannabis Music Festival
# URL: https://www.cha.guide/events/events/2024-cbd-plus-cannabis-music-festival
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Coolidge Park
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-23
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-51
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Intermission - A celebration of the arts in Chattanooga
# URL: https://www.cha.guide/events/events/intermission-a-celebration-of-the-arts-in-chattanooga
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Chattanooga Theater Center
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-24
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-47
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: KIC Food Truck Festival & Expo
# URL: https://www.cha.guide/events/events/kic-food-truck-festival-expo
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Kitchen Incubator of Chattanooga
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-52
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: OVO – a buzzing Cirque du Soleil spectacular
# URL: https://www.cha.guide/events/events/ovo-a-buzzing-cirque-du-soleil-spectacular
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: McKenzie Arena
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-48
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-53
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-54
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-49
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-55
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Candlelight: A Haunted Evening of Halloween Classics
# URL: https://www.cha.guide/events/events/candlelight-a-haunted-evening-of-halloween-classics
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: The Beverly Ballroom at Hotel Chalet
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-50
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-56
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-57
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-58
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Date Night at Frothy Monkey
# URL: https://www.cha.guide/events/events/date-night-at-frothy-monkey-2
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Frothy Monkey
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-59
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-60
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-61
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-62
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: WHITECHAPEL "TENNESSEE TAKEOVER 2024"
# URL: https://www.cha.guide/events/events/whitechapel-tennessee-takeover-2024
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: The Signal
# Recurrence:
# ----------------------------------------
# Fetching and parsing Chattanooga Pulse
# Length of parsed content: 94110
# Searching for content list with: {'div': {'id': 'event_list_div'}}
# Attempting to find content list by id: event_list_div
# Found 20 items with specified attributes
# Extracted 20 events
# Title: Gate 11 Monday Night Blues Jam
# URL:
# Date: 2024-08-05
# Start Time: 20:00
# End Time: 22:00
# Image URL: https://www.chattanoogapulse.com/downloads/26536/download/346267141_793828828666148_8086156455016631366_n.jpg?cb=3c93c436848f16af9266385cc275f4b8&w=220&h=
# Location: Gate 11 Monday Night Blues Jam
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Title: Joggers & Lagers
# URL:
# Date: 2024-08-06
# Start Time: 18:00
# End Time: 19:00
# Image URL: https://www.chattanoogapulse.com/downloads/16190/download/joggers%20%26%20lagers.png?cb=ccf918643a4c2d1a569ebfe82f3ddd7c&w=220&h=
# Location: Joggers & Lagers
# Recurrence: Outdoor, This & That
# ----------------------------------------
# Title: Paths to Pints along the Riverwalk
# URL:
# Date: 2024-08-06
# Start Time: 18:30
# End Time: None
# Image URL: https://www.chattanoogapulse.com/downloads/16001/download/Paths%20to%20Pints.png?cb=7f42636cc48cbabbf35f99d0f4b8e3ae&w=220&h=
# Location: Paths to Pints along the Riverwalk
# Recurrence: Food & Drink, Outdoor
# ----------------------------------------
# Title: Danimal And Friends
# URL:
# Date: 2024-08-06
# Start Time: 19:00
# End Time: 20:30
# Image URL: https://www.chattanoogapulse.com/downloads/16361/download/Danimal%20And%20Friends%202.png?cb=ef6c5023aa32382083cfe862b4bbe0ea&w=220&h=
# Location: Danimal And Friends
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Title: Introduction to Calm Abiding Meditation
# URL:
# Date: 2024-08-06
# Start Time: 19:00
# End Time: 20:30
# Image URL: https://www.chattanoogapulse.com/downloads/29818/download/IMG_2882.jpeg?cb=b0051075fdfe7f7f4641797a5610fde5&w=220&h=
# Location: Introduction to Calm Abiding Meditation
# Recurrence: Education & Learning, Health & Wellness
# ----------------------------------------
# Title: Main Street Farmers Market
# URL:
# Date: 2024-08-07
# Start Time: 16:00
# End Time: 18:00
# Image URL: https://www.chattanoogapulse.com/downloads/15605/download/main%20street%20market%20new.png?cb=ae85f55f8c57352275b7718935c83aef&w=220&h=
# Location: Main Street Farmers Market
# Recurrence: Markets
# ----------------------------------------
# Title: Teni Rane 'Goldenrod' Album Release Celebration
# URL:
# Date: 2024-08-07
# Start Time: 18:00
# End Time: 20:00
# Image URL: https://www.chattanoogapulse.com/downloads/30574/download/Teni-Rane-Goldenrod-Album-Release-Show-Yellow-Racket-Records-August-7-2024.jpg?cb=13f3f2ed9f4b4c175f91f9fbf581e4c0&w=220&h=
# Location: Teni Rane 'Goldenrod' Album Release Celebration
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Title: Wine Wednesday with Sam Steadman
# URL:
# Date: 2024-08-07
# Start Time: 18:00
# End Time: 20:00
# Image URL: ...: Wine Wednesday with Sam Steadman
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Title: Fleet Feet x Oddstory Pub Run
# URL:
# Date: 2024-08-07
# Start Time: 18:00
# End Time: 21:00
# Image URL: ...: Fleet Feet x Oddstory Pub Run
# Recurrence: Outdoor
# ----------------------------------------
# Title: Board Game Night
# URL:
# Date: 2024-08-07
# Start Time: 18:30
# End Time: 22:00
# Image URL: ...: Board Game Night
# Recurrence: This & That
# ----------------------------------------
# Title: Beginner I Bachata Dance Course - August
# URL:
# Date: 2024-08-07
# Start Time: 19:00
# End Time: 20:00
# Image URL: ...: Beginner I Bachata Dance Course - August
# Recurrence: This & That
# ----------------------------------------
# Title: Josey Clay
# URL:
# Date: 2024-08-07
# Start Time: 19:00
# End Time: 21:00
# Image URL: ...: Josey Clay
# Recurrence: Concerts & Live Music, Food & Drink
# ----------------------------------------
# Title: Ooltewah Farmers Market
# URL:
# Date: 2024-08-08
# Start Time: 15:00
# End Time: 17:00
# Image URL: ...: Ooltewah Farmers Market
# Recurrence: Markets
# ----------------------------------------
# Title: Create & Sip: Art Deco Embroidery
# URL:
# Date: 2024-08-08
# Start Time: 18:00
# End Time: 19:30
# Image URL: ...: Create & Sip: Art Deco Embroidery
# Recurrence: Art & Exhibitions
# ----------------------------------------
# Title: Live Music with Matt Downer
# URL:
# Date: 2024-08-08
# Start Time: 18:00
# End Time: 20:00
# Image URL: ...: Live Music with Matt Downer
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Title: Live Music with Matt Downer
# URL:
# Date: 2024-08-08
# Start Time: 18:00
# End Time: 20:00
# Image URL: ...: Live Music with Matt Downer
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Title: Live Music with Jason Lyles
# URL:
# Date: 2024-08-08
# Start Time: 18:30
# End Time: 20:30
# Image URL: ...: Live Music with Jason Lyles
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Title: Improv
# URL:
# Date: 2024-08-08
# Start Time: 19:00
# End Time: 21:00
# Image URL: ...: Improv
# Recurrence: Comedy, Concerts & Live Music, Food & Drink
# ----------------------------------------
# Title: Open Mic Night
# URL:
# Date: 2024-08-08
# Start Time: 19:00
# End Time: 21:00
# Image URL: ...: Open Mic Night
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Title: Toby Hewitt
# URL:
# Date: 2024-08-08
# Start Time: 19:00
# End Time: 22:00
# Image URL: ...: Toby Hewitt
# Recurrence: Concerts & Live Music
# ----------------------------------------
