# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from datetime import datetime
import time

# Configuration
SITES = {
    "Visit Chattanooga": {
        "url": "https://www.visitchattanooga.com/events/",
        "content_list_class": {"div": "content list"},
        "item_attr": {"div": {"data-type": "events"}},
        "title": {"a": {"class": "title truncate"}},
        "date": {"span": {"class": "mini-date-container"}},
        "month": {"span": {"class": "month"}},
        "day": {"span": {"class": "day"}},
        "img": {"img": {"class": "thumb"}},
        "location": {"li": {"class": "locations truncate"}},
        "recurrence": {"li": {"class": "recurrence"}}
    },
    "CHA Guide Events": {
        "url": "https://www.cha.guide/events",
        "content_list_class": {"div": "flex-wrapper w-dyn-list"},
        "item_attr": {"div": {"class": "flex-4-columns events w-dyn-item", "role": "listitem"}},
        "title": {"h3": {"class": "event-title"}},
        "date": {"div": {"class": "event-date-div"}},
        "day": {"div": {"class": "event-card-date"}},
        "month": {"div": {"class": "event-month"}},
        "img": {"div": {"class": "event---category-circle"}},
        "location": {"div": {"class": "location-2"}},
        "recurrence": {"div": {"class": "event---category-circle"}}
    }
}

def fetch_page(url):
    options = Options()
    options.add_argument("--headless")
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)
    
    try:
        driver.get(url)
        time.sleep(10)  # Wait longer for content to load
        return driver.page_source
    except Exception as e:
        print(f"Error fetching the page: {e}")
        return None
    finally:
        driver.quit()

def parse_html(html_content):
    return BeautifulSoup(html_content, 'html.parser')

def extract_events(parsed_content, config):
    events = []
    print(f"Searching for content list with: {config['content_list_class']}")
    
    # Unpack the content_list_class dictionary
    tag, class_name = next(iter(config['content_list_class'].items()))
    content_list = parsed_content.find(tag, class_=class_name)
    
    if not content_list:
        print("Couldn't find content list")
        return events

    # Unpack the item_attr dictionary
    item_tag, item_attrs = next(iter(config['item_attr'].items()))
    items = content_list.find_all(item_tag, **item_attrs)
    
    print(f"Found {len(items)} items with specified attributes")
    
    for item in items:
        event = {}
        
        # Extract title and URL
        title_tag, title_attrs = next(iter(config['title'].items()))
        title_element = item.find(title_tag, **title_attrs)
        if title_element:
            event['title'] = title_element.text.strip()
            url_element = title_element if title_element.name == 'a' else title_element.find_parent('a')
            event['url'] = config["url"] + url_element['href'] if url_element else ''
        else:
            print("Couldn't find title element")
            continue
        
        # Extract date
        date_tag, date_attrs = next(iter(config['date'].items()))
        date_element = item.find(date_tag, **date_attrs)
        if date_element:
            month_tag, month_attrs = next(iter(config['month'].items()))
            day_tag, day_attrs = next(iter(config['day'].items()))
            month = date_element.find(month_tag, **month_attrs)
            day = date_element.find(day_tag, **day_attrs)
            if month and day:
                event_date = f"{month.text.strip()} {day.text.strip()}, {datetime.now().year}"
                event['date'] = event_date
            else:
                event['date'] = date_element.text.strip()
        else:
            event['date'] = None
        
        # Extract image URL
        if config["img"]:
            img_tag, img_attrs = next(iter(config['img'].items()))
            img_element = item.find(img_tag, **img_attrs)
            event['image_url'] = img_element.get('data-lazy-src') or img_element.get('src') if img_element else None
        else:
            event['image_url'] = None
        
        # Extract location
        location_tag, location_attrs = next(iter(config['location'].items()))
        location_element = item.find(location_tag, **location_attrs)
        event['location'] = location_element.text.strip() if location_element else None
        
        # Extract recurrence information
        recurrence_tag, recurrence_attrs = next(iter(config['recurrence'].items()))
        recurrence_element = item.find(recurrence_tag, **recurrence_attrs)
        event['recurrence'] = recurrence_element.text.strip() if recurrence_element else None
        
        events.append(event)
    
    return events

def main():
    for site_name, config in SITES.items():
        url = config["url"]
        print(f"Fetching and parsing {site_name}")
        html_content = fetch_page(url)
        if html_content:
            parsed_content = parse_html(html_content)
            print(f"Length of parsed content: {len(str(parsed_content))}")
            events = extract_events(parsed_content, config)
            print(f"Extracted {len(events)} events")
            for event in events:
                print(f"Title: {event.get('title')}")
                print(f"URL: {event.get('url')}")
                print(f"Date: {event.get('date')}")
                print(f"Image URL: {event.get('image_url')}")
                print(f"Location: {event.get('location')}")
                print(f"Recurrence: {event.get('recurrence')}")
                print("-" * 40)
        else:
            print(f"Skipping {site_name} due to fetch error")
        time.sleep(1)  # Be polite, wait a second between requests

if __name__ == "__main__":
    main()
# Out:
# Fetching and parsing Visit Chattanooga
# Length of parsed content: 493850
# Searching for content list with: {'div': 'content list'}
# Found 12 items with specified attributes
# Extracted 12 events
# Title: APC Expo in Chattanooga
# URL: https://www.visitchattanooga.com/events//event/apc-expo-in-chattanooga/20681/
# Date: Jun 28, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Screenshot-2024-05-09-at-10.49.43-AM_AA442852-E74A-2A60-418E19AE42EE4F90_aa572ea9-b912-e8fc-da74576adf2d6975.png
# Location: Chattanooga Convention Center/Meeting Information
# Recurrence: None
# ----------------------------------------
# Title: Chattanooga Lookouts vs. Rocket City Trash Pandas
# URL: https://www.visitchattanooga.com/events//event/chattanooga-lookouts-vs-rocket-city-trash-pandas/20076/
# Date: Jun 28, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Chattanooga-Lookouts-Logo_9ED00F65-C510-536F-A62E7245252B641F_9ed6a9b6-ff66-9151-9318d116dd3ead5b.png
# Location: Chattanooga Lookouts AT&T Field
# Recurrence: None
# ----------------------------------------
# Title: Chickamauga Dam Lock Through Kayak Tour with Chattanooga Guided Adventures
# URL: https://www.visitchattanooga.com/events//event/chickamauga-dam-lock-through-kayak-tour-with-chattanooga-guided-adventures/19807/
# Date: Jun 28, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/CGA-Chickamanga_17047717-561C-4434-B479C10F432C4937_42bd9946-ca66-4b83-9259ff2418b75f33.jpg
# Location: Hubert Fry Center Boatramp
# Recurrence: Recurring daily until November 10, 2024
# ----------------------------------------
# Title: Dizzy Dean TN State Tournament
# URL: https://www.visitchattanooga.com/events//event/dizzy-dean-tn-state-tournament/20914/
# Date: Jun 28, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Dizzy-Dean-Logo_1A0999A5-BAF4-74FA-B203F61FFA7EBD1D_1a0bf3b8-fca7-5084-7510b8bbe2e518f3.jpg
# Location: Summit of Softball Complex
# Recurrence: Recurring daily until June 30, 2024
# ----------------------------------------
# Title: Electric Feels: Indie Rock + Indie Dance Party
# URL: https://www.visitchattanooga.com/events//event/electric-feels%3a-indie-rock-%2b-indie-dance-party/20743/
# Date: Jun 28, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/banner_DEE5B90F-E9FA-5BA3-D771719714507DB4_dee760e4-ef0c-8c3d-abd32225901ac37e.jpg
# Location:
# Recurrence: None
# ----------------------------------------
# Title: Evening Ridge Runner
# URL: https://www.visitchattanooga.com/events//event/evening-ridge-runner/18374/
# Date: Jun 28, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Tennessee-Valley-Railroad-Museum---Evening-Ridge-Runner---31MAIN_1AFAD541-C86C-4F5D-80CE5D0A357F13FB_fdc14ef5-8c1a-4d87-94ed198fef534e1b.jpg
# Location: Tennessee Valley Railroad Museum
# Recurrence: None
# ----------------------------------------
# Title: Exhibit Admission
# URL: https://www.visitchattanooga.com/events//event/exhibit-admission/17763/
# Date: Jun 28, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Tennessee-Valley-Railroad-Museum-Exhibit-Building-03-scaled_4F4495E7-023E-49F5-89D214567AE32153_fc60f811-20ec-4b1f-80574d7f0d0d1c4a.jpg
# Location: Tennessee Valley Railroad Museum
# Recurrence: Recurring daily until December 23, 2024
# ----------------------------------------
# Title: Friday Night Wine & Live Jazz
# URL: https://www.visitchattanooga.com/events//event/friday-night-wine-%26-live-jazz/19722/
# Date: Jun 28, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/clients/chattanooga/chattanooga_default_170b93b4-2635-4fb3-84b2-7c68ad33306f.jpg
# Location: Forge Restaurant
# Recurrence: Recurring weekly on Friday until January 10, 2025
# ----------------------------------------
# Title: Live Music at Creekside Every Friday
# URL: https://www.visitchattanooga.com/events//event/live-music-at-creekside-every-friday/20183/
# Date: Jun 28, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Creekside-MARCH_68F3BB7A-E7BB-4DFD-1CB572B3D33A9392_69f12251-c45b-d9d8-ff34bbed8c4d6d21.jpg
# Location: Creekside Bar + Grille
# Recurrence: Recurring weekly on Friday until February 21, 2025
# ----------------------------------------
# Title: Mountain Bike Rental with Chattanooga Guided Adventures
# URL: https://www.visitchattanooga.com/events//event/mountain-bike-rental-with-chattanooga-guided-adventures/19809/
# Date: Jun 28, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Incline-Railway-Bike-Tour_E81C8BF8-A9AE-4386-99A3AE8E86E6EFF0_8c1b23e6-485b-4296-9d4b5d7719fd0143.jpg
# Location: Chattanooga Guided Adventures
# Recurrence: Recurring daily until January 21, 2025
# ----------------------------------------
# Title: Music  with Jesse Jungkurth
# URL: https://www.visitchattanooga.com/events//event/music-with-jesse-jungkurth/20540/
# Date: Jun 28, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/jesseJ_4845C962-0AB4-1552-43BB08A6A5CFAE13_48576a84-f14c-d248-c0fdf1fa5a3638ed.png
# Location: Comedy Catch at the Choo Choo and Backstage Bar
# Recurrence: Recurring weekly on Friday until April 4, 2025
# ----------------------------------------
# Title: Nickajack Bat Cave Kayak Tour with Chattanooga Guided Adventures
# URL: https://www.visitchattanooga.com/events//event/nickajack-bat-cave-kayak-tour-with-chattanooga-guided-adventures/19747/
# Date: Jun 28, 2024
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Nickajack-Bat-Cave-Sunset-Kayak-Tour_6F28E129-02C9-4D96-A9031235E67BFB56_4fca779d-b1b8-4613-9d4c7a0faa9487a5.jpg
# Location: Chattanooga Guided Adventures
# Recurrence: Recurring daily until October 13, 2024
# ----------------------------------------
# Fetching and parsing CHA Guide Events
# Length of parsed content: 428907
# Searching for content list with: {'div': 'flex-wrapper w-dyn-list'}
# Found 80 items with specified attributes
# Extracted 80 events
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-6
# Date: Jun 28, 2024
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-6
# Date: Jun 28, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-34
# Date: Jun 29, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-10
# Date: Jun 29, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: The Dinner Detective Comedy Mystery Dinner Show
# URL: https://www.cha.guide/events/events/the-dinner-detective-comedy-mystery-dinner-show-3
# Date: Jun 29, 2024
# Image URL: None
# Location: DoubleTree Chattanooga Hamilton Place
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-6
# Date: Jun 29, 2024
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: Open Gate Day
# URL: https://www.cha.guide/events/events/open-gate-day
# Date: Jun 29, 2024
# Image URL: None
# Location: Lula Lake Land Trust
# Recurrence:
# ----------------------------------------
# Title: Farm & Fire Dinner Party
# URL: https://www.cha.guide/events/events/farm-fire-dinner-party
# Date: Jun 29, 2024
# Image URL: None
# Location: Mac's Kitchen & Bar
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Pride Bar Crawl
# URL: https://www.cha.guide/events/events/chattanooga-pride-bar-crawl
# Date: Jun 29, 2024
# Image URL: None
# Location: Gate 11 Distillery
# Recurrence:
# ----------------------------------------
# Title: Summerween
# URL: https://www.cha.guide/events/events/summerween
# Date: Jun 29, 2024
# Image URL: None
# Location: Patten Square
# Recurrence:
# ----------------------------------------
# Title: International Food and Art Festival
# URL: https://www.cha.guide/events/events/international-food-and-art-festival
# Date: Jun 29, 2024
# Image URL: None
# Location: Old McDonald Farm
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-7
# Date: Jun 29, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Improv Comedy Show at The Chattery
# URL: https://www.cha.guide/events/events/improv-comedy-show-at-the-chattery
# Date: Jun 29, 2024
# Image URL: None
# Location: The Chattery
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-11
# Date: Jun 30, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Open Gate Day
# URL: https://www.cha.guide/events/events/open-gate-day-2
# Date: Jun 30, 2024
# Image URL: None
# Location: Lula Lake Land Trust
# Recurrence:
# ----------------------------------------
# Title: Chatta Town Tasting Festival 2024
# URL: https://www.cha.guide/events/events/chatta-town-tasting-festival-2024
# Date: Jun 30, 2024
# Image URL: None
# Location: 910 Market St
# Recurrence:
# ----------------------------------------
# Title: RED, WHITE AND BLUEBERRIES
# URL: https://www.cha.guide/events/events/red-white-and-blueberries
# Date: Jun 30, 2024
# Image URL: None
# Location: First Horizon Pavilion
# Recurrence:
# ----------------------------------------
# Title: PEACH FESTIVAL
# URL: https://www.cha.guide/events/events/peach-festival
# Date: Jun 30, 2024
# Image URL: None
# Location: First Horizon Pavilion
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-39
# Date: Jul 3, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Sensory Night @ Creative Discovery Museum
# URL: https://www.cha.guide/events/events/sensory-night-creative-discovery-museum-2
# Date: Jul 4, 2024
# Image URL: None
# Location: Creative Discovery Museum
# Recurrence:
# ----------------------------------------
# Title: Red, White, & Blue Brunch at Whitebird/The Edwin Hotel
# URL: https://www.cha.guide/events/events/red-white-blue-brunch-at-whitebird-the-edwin-hotel
# Date: Jul 4, 2024
# Image URL: None
# Location: Whitebird
# Recurrence:
# ----------------------------------------
# Title: 4th of July Ruck
# URL: https://www.cha.guide/events/events/4th-of-july-ruck
# Date: Jul 4, 2024
# Image URL: None
# Location: Greenway Farms
# Recurrence:
# ----------------------------------------
# Title: Independence Day Fireworks | Lookouts vs. Smokies
# URL: https://www.cha.guide/events/events/independence-day-fireworks-lookouts-vs-smokies
# Date: Jul 4, 2024
# Image URL: None
# Location: AT&T Field
# Recurrence:
# ----------------------------------------
# Title: Red, White, & Moon Pool Party
# URL: https://www.cha.guide/events/events/red-white-moon-pool-party
# Date: Jul 4, 2024
# Image URL: None
# Location: Whiskey Thief
# Recurrence:
# ----------------------------------------
# Title: RED, WHITE AND BLUE DAY
# URL: https://www.cha.guide/events/events/red-white-and-blue-day
# Date: Jul 4, 2024
# Image URL: None
# Location: Creative Discovery Museum
# Recurrence:
# ----------------------------------------
# Title: 4 on the 4th Pancake Run at Fleet Feet
# URL: https://www.cha.guide/events/events/4-on-the-4th-pancake-run-at-fleet-feet
# Date: Jul 4, 2024
# Image URL: None
# Location: Fleet Feet Chattanooga
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-7
# Date: Jul 5, 2024
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-8
# Date: Jul 5, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-35
# Date: Jul 6, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-12
# Date: Jul 6, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-7
# Date: Jul 6, 2024
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-9
# Date: Jul 6, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-40
# Date: Jul 10, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Free Family Night @ Creative Discovery Museum
# URL: https://www.cha.guide/events/events/free-family-night-creative-discovery-museum-3
# Date: Jul 11, 2024
# Image URL: None
# Location: Creative Discovery Museum
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-8
# Date: Jul 12, 2024
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-10
# Date: Jul 12, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: CHATTANOOGA MARKET AT ERLANGER EAST HOSPITAL
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-east-hospital-2
# Date: Jul 12, 2024
# Image URL: None
# Location: Erlanger East Hospital
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-36
# Date: Jul 13, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-13
# Date: Jul 13, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-8
# Date: Jul 13, 2024
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-11
# Date: Jul 13, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: 2024 SAFE AND CONSERVATION AWARENESS DAY
# URL: https://www.cha.guide/events/events/2024-safe-and-conservation-awareness-day-3
# Date: Jul 13, 2024
# Image URL: None
# Location: Chattanooga Zoo
# Recurrence:
# ----------------------------------------
# Title: 1964 The Tribute @ Walker Theatre
# URL: https://www.cha.guide/events/events/1964-the-tribute-walker-theatre
# Date: Jul 14, 2024
# Image URL: None
# Location: Walker Theatre
# Recurrence:
# ----------------------------------------
# Title: TOP TOMATO BLOODY MARY
# URL: https://www.cha.guide/events/events/top-tomato-bloody-mary
# Date: Jul 14, 2024
# Image URL: None
# Location: First Horizon Pavilion
# Recurrence:
# ----------------------------------------
# Title: Buddy Guy - Damn Right Encore
# URL: https://www.cha.guide/events/events/buddy-guy---damn-right-encore
# Date: Jul 16, 2024
# Image URL: None
# Location: Soldiers and Sailors Memorial Auditorium
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-41
# Date: Jul 17, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-9
# Date: Jul 19, 2024
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-12
# Date: Jul 19, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-37
# Date: Jul 20, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-14
# Date: Jul 20, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: The Dinner Detective Comedy Mystery Dinner Show
# URL: https://www.cha.guide/events/events/the-dinner-detective-comedy-mystery-dinner-show-4
# Date: Jul 20, 2024
# Image URL: None
# Location: DoubleTree Chattanooga Hamilton Place
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-9
# Date: Jul 20, 2024
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-13
# Date: Jul 20, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: FIVESTAR FOOD FIGHT
# URL: https://www.cha.guide/events/events/fivestar-food-fight
# Date: Jul 21, 2024
# Image URL: None
# Location: First Horizon Pavilion
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-42
# Date: Jul 24, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Paul Belcher Presents The Inspirations 60 Year Reunion 60 Yr Reunion w/McKamey Legacy
# URL: https://www.cha.guide/events/events/paul-belcher-presents-the-inspirations-60-year-reunion-60-yr-reunion-w-mckamey-legacy
# Date: Jul 26, 2024
# Image URL: None
# Location: Walker Theatre
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-10
# Date: Jul 26, 2024
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-14
# Date: Jul 26, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-38
# Date: Jul 27, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-15
# Date: Jul 27, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-10
# Date: Jul 27, 2024
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-15
# Date: Jul 27, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: CHATTANOOGA BLUEGRASS
# URL: https://www.cha.guide/events/events/chattanooga-bluegrass
# Date: Jul 28, 2024
# Image URL: None
# Location: First Horizon Pavilion
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-43
# Date: Jul 31, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Sensory Night @ Creative Discovery Museum
# URL: https://www.cha.guide/events/events/sensory-night-creative-discovery-museum-3
# Date: Aug 1, 2024
# Image URL: None
# Location: Creative Discovery Museum
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-11
# Date: Aug 2, 2024
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-16
# Date: Aug 2, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-39
# Date: Aug 3, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-16
# Date: Aug 3, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-11
# Date: Aug 3, 2024
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-17
# Date: Aug 3, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Pirates, Parrots, and Princesses
# URL: https://www.cha.guide/events/events/pirates-parrots-and-princesses
# Date: Aug 3, 2024
# Image URL: None
# Location: Chattanooga Zoo
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-44
# Date: Aug 7, 2024
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Free Family Night @ Creative Discovery Museum
# URL: https://www.cha.guide/events/events/free-family-night-creative-discovery-museum-4
# Date: Aug 8, 2024
# Image URL: None
# Location: Creative Discovery Museum
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-12
# Date: Aug 9, 2024
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-18
# Date: Aug 9, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-40
# Date: Aug 10, 2024
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-17
# Date: Aug 10, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-12
# Date: Aug 10, 2024
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-19
# Date: Aug 10, 2024
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------

# %% [markdown]
# # the following works for visit chattanooga

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from datetime import datetime
import time

# Configuration
SITES = {
    "Visit Chattanooga": {
        "url": "https://www.visitchattanooga.com/events/",
        "content_list_class": "content list",
        "item_attr": {"data-type": "events"},
        "title_class": "title truncate",
        "date_class": "mini-date-container",
        "month_class": "month",
        "day_class": "day",
        "img_class": "thumb",
        "location_class": "locations truncate",
        "recurrence_class": "recurrence"
    },
    # "Nooga Today": {
    #     "url": "https://noogatoday.6amcity.com/events#/", # preloaded_lightbox blocking site
    #     "content_list_class": "",
    #     "item_attr": {},
    #     "title_class": "",
    #     "date_class": "",
    #     "month_class": "",
    #     "day_class": "",
    #     "img_class": "",
    #     "location_class": "",
    #     "recurrence_class": ""
    # },
    # "Choose Chatt": {
    #     "url": "https://choosechatt.com/chattanooga-events/", # dialog-lightbox-message blocking site
    #     "content_list_class": "",
    #     "item_attr": {},
    #     "title_class": "",
    #     "date_class": "",
    #     "month_class": "",
    #     "day_class": "",
    #     "img_class": "",
    #     "location_class": "",
    #     "recurrence_class": ""
    # },
    "CHA Guide Events": {
        "url": "https://www.cha.guide/events",
        "content_list_class": "flex-wrapper w-dyn-list",
        "item_attr": {"role": "listitem"},
        "title_class": "event-title",
        "date_class": "event-date-div",
        "month_class": "event-month",
        "day_class": "event-card-date",
        "img_class": "",  # Add this when you have the image class (event---category-circle)
        "location_class": "location-2",
        "recurrence_class": "event---category-circle"  # This might need further adjustment
    },
    # "Chattanooga Pulse": {
    #     "url": "https://www.chattanoogapulse.com/search/event/the-pulse-event-search/#page=1",
    #     "content_list_class": "",
    #     "item_attr": {},
    #     "title_class": "",
    #     "date_class": "",
    #     "month_class": "",
    #     "day_class": "",
    #     "img_class": "",
    #     "location_class": "",
    #     "recurrence_class": ""
    # },
    # "Times Free Press": {
    #     "url": "https://www.timesfreepress.com/tfpevents/?_evDiscoveryPath=/",
    #     "content_list_class": "",
    #     "item_attr": {},
    #     "title_class": "",
    #     "date_class": "",
    #     "month_class": "",
    #     "day_class": "",
    #     "img_class": "",
    #     "location_class": "",
    #     "recurrence_class": ""
    # },
    # "CHA Guide Weekly": {
    #     "url": "https://www.cha.guide/explore/things-to-do-in-chattanooga-this-week",
    #     "content_list_class": "",
    #     "item_attr": {},
    #     "title_class": "",
    #     "date_class": "",
    #     "month_class": "",
    #     "day_class": "",
    #     "img_class": "",
    #     "location_class": "",
    #     "recurrence_class": ""
    # },
    # "Chattanooga Chamber": {
    #     "url": "https://chattanoogachamber.com/",
    #     "content_list_class": "",
    #     "item_attr": {},
    #     "title_class": "",
    #     "date_class": "",
    #     "month_class": "",
    #     "day_class": "",
    #     "img_class": "",
    #     "location_class": "",
    #     "recurrence_class": ""
    # },
    # "Chattanooga Library": {
    #     "url": "https://www.chattlibrary.org/events/",
    #     "content_list_class": "",
    #     "item_attr": {},
    #     "title_class": "",
    #     "date_class": "",
    #     "month_class": "",
    #     "day_class": "",
    #     "img_class": "",
    #     "location_class": "",
    #     "recurrence_class": ""
    # }
}

def fetch_page(url):
    options = Options()
    options.add_argument("--headless")  # Run in headless mode (no GUI)
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)
    
    try:
        driver.get(url)
        time.sleep(5)  # Wait for JavaScript to load content
        return driver.page_source
    except Exception as e:
        print(f"Error fetching the page: {e}")
        return None
    finally:
        driver.quit()

def parse_html(html_content):
    return BeautifulSoup(html_content, 'html.parser')

def extract_events(parsed_content, config):
    events = []
    content_list = parsed_content.find('div', class_=config["content_list_class"])
    if not content_list:
        print("Couldn't find 'content list' div")
        return events

    items = content_list.find_all('div', attrs=config["item_attr"])
    print(f"Found {len(items)} items with specified attributes")
    
    for item in items:
        event = {}
        
        # Extract title and URL
        title_element = item.find('a', class_=config["title_class"])
        if title_element:
            event['title'] = title_element.text.strip()
            event['url'] = config["url"] + title_element['href']
        else:
            print("Couldn't find title element")
            continue
        
        # Extract date
        date_element = item.find('span', class_=config["date_class"])
        if date_element:
            month = date_element.find('span', class_=config["month_class"])
            day = date_element.find('span', class_=config["day_class"])
            if month and day:
                event_date = f"{month.text} {day.text}, {datetime.now().year}"
                try:
                    event['date'] = datetime.strptime(event_date, '%b %d, %Y').date()
                except ValueError:
                    event['date'] = event_date  # Keep the original format if parsing fails
            else:
                print("Couldn't find month or day")
        else:
            print("Couldn't find date element")
        
        # Extract image URL
        img_element = item.find('img', class_=config["img_class"])
        event['image_url'] = img_element['data-lazy-src'] if img_element else None
        
        # Extract location
        location_element = item.find('li', class_=config["location_class"])
        event['location'] = location_element.text.strip() if location_element else None
        
        # Extract recurrence information
        recurrence_element = item.find('li', class_=config["recurrence_class"])
        event['recurrence'] = recurrence_element.text.strip() if recurrence_element else None
        
        events.append(event)
    
    return events

def main():
    for site_name, config in SITES.items():
        url = config["url"]
        print(f"Fetching and parsing {site_name}")
        html_content = fetch_page(url)  # This should be using Selenium
        if html_content:
            parsed_content = parse_html(html_content)
            print(f"Length of parsed content: {len(str(parsed_content))}")
            events = extract_events(parsed_content, config)
            print(f"Extracted {len(events)} events")
            for event in events:
                print(f"Title: {event.get('title')}")
                print(f"URL: {event.get('url')}")
                print(f"Date: {event.get('date')}")
                print(f"Image URL: {event.get('image_url')}")
                print(f"Location: {event.get('location')}")
                print(f"Recurrence: {event.get('recurrence')}")
                print("-" * 40)
        else:
            print(f"Skipping {site_name} due to fetch error")
        time.sleep(1)  # Be polite, wait a second between requests

if __name__ == "__main__":
    main()
# Out:
# Fetching and parsing Visit Chattanooga
# Length of parsed content: 493386
# Found 12 items with specified attributes
# Extracted 12 events
# Title: APC Expo in Chattanooga
# URL: https://www.visitchattanooga.com/events//event/apc-expo-in-chattanooga/20681/
# Date: 2024-06-28
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Screenshot-2024-05-09-at-10.49.43-AM_AA442852-E74A-2A60-418E19AE42EE4F90_aa572ea9-b912-e8fc-da74576adf2d6975.png
# Location: Chattanooga Convention Center/Meeting Information
# Recurrence: None
# ----------------------------------------
# Title: Chattanooga Lookouts vs. Rocket City Trash Pandas
# URL: https://www.visitchattanooga.com/events//event/chattanooga-lookouts-vs-rocket-city-trash-pandas/20076/
# Date: 2024-06-28
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Chattanooga-Lookouts-Logo_9ED00F65-C510-536F-A62E7245252B641F_9ed6a9b6-ff66-9151-9318d116dd3ead5b.png
# Location: Chattanooga Lookouts AT&T Field
# Recurrence: None
# ----------------------------------------
# Title: Chickamauga Dam Lock Through Kayak Tour with Chattanooga Guided Adventures
# URL: https://www.visitchattanooga.com/events//event/chickamauga-dam-lock-through-kayak-tour-with-chattanooga-guided-adventures/19807/
# Date: 2024-06-28
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/CGA-Chickamanga_17047717-561C-4434-B479C10F432C4937_42bd9946-ca66-4b83-9259ff2418b75f33.jpg
# Location: Hubert Fry Center Boatramp
# Recurrence: Recurring daily until November 10, 2024
# ----------------------------------------
# Title: Dizzy Dean TN State Tournament
# URL: https://www.visitchattanooga.com/events//event/dizzy-dean-tn-state-tournament/20914/
# Date: 2024-06-28
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Dizzy-Dean-Logo_1A0999A5-BAF4-74FA-B203F61FFA7EBD1D_1a0bf3b8-fca7-5084-7510b8bbe2e518f3.jpg
# Location: Summit of Softball Complex
# Recurrence: Recurring daily until June 30, 2024
# ----------------------------------------
# Title: Electric Feels: Indie Rock + Indie Dance Party
# URL: https://www.visitchattanooga.com/events//event/electric-feels%3a-indie-rock-%2b-indie-dance-party/20743/
# Date: 2024-06-28
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/banner_DEE5B90F-E9FA-5BA3-D771719714507DB4_dee760e4-ef0c-8c3d-abd32225901ac37e.jpg
# Location:
# Recurrence: None
# ----------------------------------------
# Title: Evening Ridge Runner
# URL: https://www.visitchattanooga.com/events//event/evening-ridge-runner/18374/
# Date: 2024-06-28
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Tennessee-Valley-Railroad-Museum---Evening-Ridge-Runner---31MAIN_1AFAD541-C86C-4F5D-80CE5D0A357F13FB_fdc14ef5-8c1a-4d87-94ed198fef534e1b.jpg
# Location: Tennessee Valley Railroad Museum
# Recurrence: None
# ----------------------------------------
# Title: Exhibit Admission
# URL: https://www.visitchattanooga.com/events//event/exhibit-admission/17763/
# Date: 2024-06-28
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Tennessee-Valley-Railroad-Museum-Exhibit-Building-03-scaled_4F4495E7-023E-49F5-89D214567AE32153_fc60f811-20ec-4b1f-80574d7f0d0d1c4a.jpg
# Location: Tennessee Valley Railroad Museum
# Recurrence: Recurring daily until December 23, 2024
# ----------------------------------------
# Title: Friday Night Wine & Live Jazz
# URL: https://www.visitchattanooga.com/events//event/friday-night-wine-%26-live-jazz/19722/
# Date: 2024-06-28
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/clients/chattanooga/chattanooga_default_170b93b4-2635-4fb3-84b2-7c68ad33306f.jpg
# Location: Forge Restaurant
# Recurrence: Recurring weekly on Friday until January 10, 2025
# ----------------------------------------
# Title: Live Music at Creekside Every Friday
# URL: https://www.visitchattanooga.com/events//event/live-music-at-creekside-every-friday/20183/
# Date: 2024-06-28
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Creekside-MARCH_68F3BB7A-E7BB-4DFD-1CB572B3D33A9392_69f12251-c45b-d9d8-ff34bbed8c4d6d21.jpg
# Location: Creekside Bar + Grille
# Recurrence: Recurring weekly on Friday until February 21, 2025
# ----------------------------------------
# Title: Mountain Bike Rental with Chattanooga Guided Adventures
# URL: https://www.visitchattanooga.com/events//event/mountain-bike-rental-with-chattanooga-guided-adventures/19809/
# Date: 2024-06-28
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Incline-Railway-Bike-Tour_E81C8BF8-A9AE-4386-99A3AE8E86E6EFF0_8c1b23e6-485b-4296-9d4b5d7719fd0143.jpg
# Location: Chattanooga Guided Adventures
# Recurrence: Recurring daily until January 21, 2025
# ----------------------------------------
# Title: Music  with Jesse Jungkurth
# URL: https://www.visitchattanooga.com/events//event/music-with-jesse-jungkurth/20540/
# Date: 2024-06-28
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/jesseJ_4845C962-0AB4-1552-43BB08A6A5CFAE13_48576a84-f14c-d248-c0fdf1fa5a3638ed.png
# Location: Comedy Catch at the Choo Choo and Backstage Bar
# Recurrence: Recurring weekly on Friday until April 4, 2025
# ----------------------------------------
# Title: Nickajack Bat Cave Kayak Tour with Chattanooga Guided Adventures
# URL: https://www.visitchattanooga.com/events//event/nickajack-bat-cave-kayak-tour-with-chattanooga-guided-adventures/19747/
# Date: 2024-06-28
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Nickajack-Bat-Cave-Sunset-Kayak-Tour_6F28E129-02C9-4D96-A9031235E67BFB56_4fca779d-b1b8-4613-9d4c7a0faa9487a5.jpg
# Location: Chattanooga Guided Adventures
# Recurrence: Recurring daily until October 13, 2024
# ----------------------------------------
# Fetching and parsing CHA Guide Events
# Length of parsed content: 428894
# Found 80 items with specified attributes
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Couldn't find title element
# Extracted 0 events
