# %%
from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import chromedriver_autoinstaller
from bs4 import BeautifulSoup
from datetime import datetime
from dateutil import parser
import time
import re

####################
# CONFIGURATION
####################

SITES = {

    "Visit Chattanooga": {
        "url": "https://www.visitchattanooga.com/events/",
        "content_list_class": {"div": {"class": "content grid"}},
        "item_attr": {"div": {"data-type": "events"}},
        "title": {"a": {"class": "title truncate"}},
        "date": {"span": {"class": "mini-date-container"}}, # now broken since dateutil. Check for start and end times
        "img": { # Need to display as image
            "img": {"class": "thumb"},
            "parse_method": "lazy-src"
        },
        "location": {"li": {"class": "locations truncate"}},
        "recurrence": {"li": {"class": "recurrence"}},
    },

    "CHA Guide Events": {
        "url": "https://www.cha.guide/events",
        "content_list_class": {"div": {"class": "flex-table w-dyn-items"}},
        "item_attr": {"div": {"role": "listitem"}},
        "title": {"h3": {"class": "event-title"}},
        "date": {"div": {"class": "event-date-div"}}, # now broken since dateutil. Check for start and end times
        "img": {
            "parse_method": "none",
        },
        "location": {"div": {"class": "location-2"}},
        "recurrence": {"div": {"class": "event---category-circle"}},
        "category": {"div": {"class": "event---category-circle"}},
        "details": {"div": {"class": "smaller-text bottom-margin---5px"}},
    },
    
    "Chattanooga Pulse": {
        "url": "https://www.chattanoogapulse.com/search/event/the-pulse-event-search/#page=1", # no event url
        "content_list_class": {"div": {"id": "event_list_div"}},
        "item_attr": {"div": {"class": "event_result"}},
        "title": {"h4": {"class": "event_title"}},
        "date": {"p": {"class": "event_date"}}, # need to format as AM/PM
        "img": { # Need to display as image
            "container": {"div": {"class": "event_thumb"}},
            "tag": "img",
            "attr": "srcset",
            "parse_method": "srcset_220w"
        },
        "location": {"a": {}}, # outputs title instead of location
        "recurrence": {"p": {"class": "cats"}},
        "details": {"div": {"class": "smaller-text bottom-margin---5px"}},

    },
    
    # "Nooga Today": {
    #     "url": "https://noogatoday.6amcity.com/events#/", # preloaded_lightbox blocking site
    #     },
    
    # "Choose Chatt": {
    #     "url": "https://choosechatt.com/chattanooga-events/", # dialog-lightbox-message blocking site
    # },

    "Times Free Press": {
        "url": "https://www.timesfreepress.com/tfpevents/?_evDiscoveryPath=/",
        "content_list_class": {"div": {"class": "grid"}},
        "item_attr": {"div": {"class": "c-card"}},
        "title": {"h3": {}},
        "date": {"div": {"class": "rounded-r"}},
        "img": {
            "img": {"class": "event-image"},
            "parse_method": "src"
        },
        "location": {"li": {"class": "line-clamp-1"}},
        "recurrence": None,  # No clear recurrence information in the provided HTML
        "time": {"li": {"class": None}},  # The first <li> element contains the time
        "price": {"li": None}  # The last <li> element contains the price
    },

    # "CHA Guide Weekly": {
    #     "url": "https://www.cha.guide/explore/things-to-do-in-chattanooga-this-week",
    # },

    # "Chattanooga Chamber": {
    #     "url": "https://chattanoogachamber.com/",
    # },

    # "Chattanooga Library": {
    #     "url": "https://www.chattlibrary.org/events/",
    # }

}

####################
# FETCHING & PARSING
####################

def fetch_page(url):
    # options = Options()
    # options.add_argument("--headless")  # Run in headless mode (no GUI)
    # service = Service(ChromeDriverManager().install())
    chromedriver_autoinstaller.install()
    driver = webdriver.Chrome()
    
    try:
        driver.get(url)
        time.sleep(5)  # Wait for JavaScript to load content
        check_shadow_dom(driver) #DEBUGGING
        scroll_page(driver) #DEBUGGING
        return driver.page_source
    except Exception as e:
        print(f"Error fetching the page: {e}")
        return None
    finally:
        driver.quit()

def parse_html(html_content):
    return BeautifulSoup(html_content, 'html.parser')

####################
# DEBUGGING 
####################

def grid_search(html_content):
    grid_match = re.search(r'<div[^>]*class="[^"]*grid[^"]*"', html_content)
    if grid_match:
        start = max(0, grid_match.start() - 500)
        end = min(len(html_content), grid_match.end() + 1000)
        print(html_content[start:end])
    else:
        print("Could not find 'grid' class in the HTML")

def find_iframes(html_content):
    iframes = parsed_content.find_all('iframe')
    for iframe in iframes:
        print(f"Found iframe: {iframe.get('src', 'No src attribute')}")

def check_shadow_dom(driver):
    shadow_hosts = driver.execute_script("""
        return Array.from(document.querySelectorAll('*')).filter(el => el.shadowRoot);
    """)
    for host in shadow_hosts:
        print(f"Found Shadow DOM host: {host.tag_name}, id: {host.get_attribute('id')}")

def find_potential_containers(parsed_content):
    potential_containers = parsed_content.find_all('div', class_=lambda x: x and any(keyword in x.lower() for keyword in ['list', 'container', 'wrapper', 'events']))
    for container in potential_containers:
        print(f"Potential container found: {container.get('class')}")

def scroll_page(driver):
    total_height = driver.execute_script("return document.body.scrollHeight")
    for i in range(1, total_height, 100):
        driver.execute_script(f"window.scrollTo(0, {i});")
        time.sleep(0.1)

def save_html(html_content, site_name):
    with open(f'{site_name}.html', 'w', encoding='utf-8') as f:
        f.write(html_content)





####################
# EXTRACTION 
####################

def extract_image_url(img_config, item):
    if img_config['parse_method'] == 'lazy-src':
        img_tag, img_attrs = next(iter(img_config.items()))
        img_element = item.find(img_tag, **img_attrs)
        return img_element.get('data-lazy-src') or img_element.get('src') if img_element else None

    elif img_config['parse_method'] == 'srcset_220w':
        container_tag, container_attrs = next(iter(img_config['container'].items()))
        container = item.find(container_tag, **container_attrs)
        if not container:
            return None

        img_element = container.find(img_config['tag'])
        if not img_element or img_config['attr'] not in img_element.attrs:
            return None

        srcset = img_element[img_config['attr']]
        urls = srcset.split(', ')
        for url in urls:
            if '220w' in url:
                return url.split(' ')[0]
        return urls[0].split(' ')[0] if urls else None

    elif img_config['parse_method'] == 'none':
        return None
    
    # Add other parsing methods here if needed
    
    return None

def parse_date_range(date_text):
    # Regular expression to match date, start time, and end time
    pattern = r'(\w+ \d+, \d{4})(?: (\d+:\d+ [AP]M))?(?: - (\d+:\d+ [AP]M))?'
    match = re.match(pattern, date_text)
    
    if match:
        date_str, start_time, end_time = match.groups()
        
        try:
            # Parse the date
            parsed_date = parser.parse(date_str)
            date = parsed_date.strftime("%Y-%m-%d")
            
            # Parse start time if available
            start = None
            if start_time:
                start = parser.parse(f"{date_str} {start_time}").strftime("%H:%M")
            
            # Parse end time if available
            end = None
            if end_time:
                end = parser.parse(f"{date_str} {end_time}").strftime("%H:%M")
            
            return {
                'date': date,
                'start_time': start,
                'end_time': end
            }
        except ValueError:
            print(f"Couldn't parse date: {date_text}")
    
    return {
        'date': None,
        'start_time': None,
        'end_time': None
    }

# TODO: category function

# TODO: details function

def extract_events(parsed_content, config):
    events = []
    print(f"Searching for content list with: {config['content_list_class']}")
    
    # Unpack the content_list_class dictionary
    tag, class_name = next(iter(config['content_list_class'].items()))
    
    content_list = None
    
    # Try to find content list by id first
    try:
        if 'id' in class_name:
            content_list = parsed_content.find(tag, id=class_name['id'])
            print(f"Attempting to find content list by id: {class_name['id']}")
    except Exception as e:
        print(f"Error when searching by id: {e}")

    # If not found by id, try to find by class
    if not content_list:
        try:
            if 'class' in class_name:
                content_list = parsed_content.find(tag, class_=class_name['class'])
                print(f"Attempting to find content list by class: {class_name['class']}")
        except Exception as e:
            print(f"Error when searching by class: {e}")

    # If still not found, try to find without any attributes
    if not content_list:
        try:
            content_list = parsed_content.find(tag)
            print(f"Attempting to find content list by tag: {tag}")
        except Exception as e:
            print(f"Error when searching by tag: {e}")

    if not content_list:
        print("Couldn't find content list")
        return events

    # print(f"Found content list: {content_list}")

    # Unpack the item_attr dictionary
    item_tag, item_attrs = next(iter(config['item_attr'].items()))
    try:
        items = content_list.find_all(item_tag, **item_attrs)
        print(f"Found {len(items)} items with specified attributes")
    except Exception as e:
        print(f"Error when finding items: {e}")
        return events

    for item in items:
        event = {}
        
        # Extract title and URL
        try:
            title_tag, title_attrs = next(iter(config['title'].items()))
            title_element = item.find(title_tag, **title_attrs)
            if title_element:
                event['title'] = title_element.text.strip()
                url_element = title_element if title_element.name == 'a' else title_element.find_parent('a')
                event['url'] = config["url"] + url_element['href'] if url_element else ''
            else:
                print("Couldn't find title element")
                continue
        except Exception as e:
            print(f"Error extracting title: {e}")
            continue

        # Extract date and times
        try:
            date_tag, date_attrs = next(iter(config['date'].items()))
            date_element = item.find(date_tag, **date_attrs)
            if date_element:
                date_text = date_element.text.strip()
                date_info = parse_date_range(date_text)
                event.update(date_info)
            else:
                event.update({
                    'date': None,
                    'start_time': None,
                    'end_time': None
                })
        except Exception as e:
            print(f"Error extracting date: {e}")

        # Extract image URL
        try:
            if config.get("img"):
                event['image_url'] = extract_image_url(config["img"], item)
            else:
                event['image_url'] = None
        except Exception as e:
            print(f"Error extracting image URL: {e}")
            event['image_url'] = None

        # Extract location
        try:
            location_tag, location_attrs = next(iter(config['location'].items()))
            location_element = item.find(location_tag, **location_attrs)
            event['location'] = location_element.text.strip() if location_element else None
        except Exception as e:
            print(f"Error extracting location: {e}")
            event['location'] = None

        # Extract recurrence information
        try:
            recurrence_tag, recurrence_attrs = next(iter(config['recurrence'].items()))
            recurrence_element = item.find(recurrence_tag, **recurrence_attrs)
            event['recurrence'] = recurrence_element.text.strip() if recurrence_element else None
        except Exception as e:
            print(f"Error extracting recurrence: {e}")
            event['recurrence'] = None

        events.append(event)
    
    return events

####################
# EXECUTION
####################

def main():
    for site_name, config in SITES.items():
        url = config["url"]
        print(f"Fetching and parsing {site_name}")

        html_content = fetch_page(url)
        if html_content:
            save_html(html_content, site_name) #DEBUGGING
            grid_search(html_content) #DEBUGGING
            
            parsed_content = parse_html(html_content)
            print(f"Length of parsed content: {len(str(parsed_content))}")
            find_potential_containers(parsed_content) # DEBUGGING
            # find_iframes(html_content) #DEBUGGING
            events = extract_events(parsed_content, config)
            print(f"Extracted {len(events)} events")
            for event in events:
                print(f"Title: {event.get('title')}")
                print(f"URL: {event.get('url')}")
                print(f"Date: {event.get('date')}")
                print(f"Start Time: {event.get('start_time')}")
                print(f"End Time: {event.get('end_time')}")
                print(f"Image URL: {event.get('image_url')}")
                print(f"Location: {event.get('location')}")
                print(f"Recurrence: {event.get('recurrence')}")
                print("-" * 40)
        else:
            print(f"Skipping {site_name} due to fetch error")
        time.sleep(1)  # Be polite, wait a second between requests

if __name__ == "__main__":
    main()



####################
# BUGS & TODOS
####################


# TODO: category function

# TODO: details function

# BUG: rewrite date function to work on all sites (output times as AM/PM)

# TODO: add a time and price function (time could be included in date function)

# TODO: pull individual functions out of extract_events

# TODO: display image link as an image instead of a url

# BUG: fix event url and location in pulse

# TODO: consider adding capture network requests
# Capture network requests
        # logs = driver.get_log('performance')
        # for log in logs:
        #     network_log = json.loads(log['message'])['message']
        #     if ('Network.response' in network_log['method'] 
        #         or 'Network.request' in network_log['method']
        #         or 'Network.webSocket' in network_log['method']):
        #         print(network_log)

####################
# THINGS DONE
####################

###
# 8-6-24
###

# Started adding times free press
    # debugging: failed to find content list class
        # grid search function added
        # find iframes function added
        # check shadow dom function added (event list appears to be in shadow dom
        # find potential containers function added
        # scroll page function added
        # save html function added

# Consolidated debugging functions into a single section for readability and maintainability
# Out:
# Fetching and parsing Visit Chattanooga
# entRender_type_widget contentRender_name_plugins_common_embed" data-sv-time="61" data-sv-index="16" data-gtm-vars="{ &quot;tCore&quot; : { &quot;contentNum&quot; : &quot;1&quot; } }"><div class="custom-embed" data-guid="708220df-3229-4acf-ab8e-25ec1361dee0">
#     <script id="cr-init__a35f8e0291db91cd" src="https://starling.crowdriff.com/js/crowdriff.js" async=""></script><div id="cr__a35f8e0291db91cd"><div id="cr__app" class="cr__gallery cr__gallery__isGalleryRefresh" style="overflow-x: hidden;"><div class="cr__grid clearfix" id="a35f8e0291db91cd" style="margin: 0px -2.5px; padding-top: 2.5px; padding-bottom: 2.5px; position: relative;"><div class="erd_scroll_detection_container erd_scroll_detection_container_animation_active" style="visibility: hidden; display: inline; width: 0px; height: 0px; z-index: -1; overflow: hidden; margin: 0px; padding: 0px;"><div dir="ltr" class="erd_scroll_detection_container" style="position: absolute; flex: 0 0 auto; overflow: hidden; z-index: -1; visibility: hidden; width: 100%; height: 100%; left: 0px; top: 0px;"><div class="erd_scroll_detection_container" style="position: absolute; flex: 0 0 auto; overflow: hidden; z-index: -1; visibility: hidden; inset: -16px -15px -15px -16px;"><div style="position: absolute; flex: 0 0 auto; overflow: scroll; z-index: -1; visibility: hidden; width: 100%; height: 100%;"><div style="position: absolute; left: 0px; top: 0px; width: 1659px; height: 318px;"></div></div><div style="position: absolute; flex: 0 0 auto; overflow: scroll; z-index:
# Length of parsed content: 560495
# Potential container found: ['header-container']
# Potential container found: ['nav-container', 'secondary']
# Potential container found: ['nav-container']
# Potential container found: ['weather-wrapper']
# Potential container found: ['forecast-wrapper']
# Potential container found: ['temp-wrapper']
# Potential container found: ['forecast-list']
# Potential container found: ['weather-wrapper']
# Potential container found: ['forecast-wrapper']
# Potential container found: ['temp-wrapper']
# Potential container found: ['forecast-list']
# Potential container found: ['slideshow-container']
# Potential container found: ['contentRender', 'contentRender_9', 'contentRender_type_panel', 'contentRender_name_plugins_common_container_intro']
# Potential container found: ['contentRender', 'contentRender_10', 'contentRender_type_panel', 'contentRender_name_plugins_common_container_navigation_share']
# Potential container found: ['navigation-container']
# Potential container found: ['share-container']
# Potential container found: ['sv-share-button-wrapper']
# Potential container found: ['content-wrapper', 'truncated']
# Potential container found: ['read-more-wrapper']
# Potential container found: ['slick-list', 'draggable']
# Potential container found: ['erd_scroll_detection_container', 'erd_scroll_detection_container_animation_active']
# Potential container found: ['erd_scroll_detection_container']
# Potential container found: ['erd_scroll_detection_container']
# Potential container found: ['iconWrapper', 'iconWrapper', 'cameraIcon', 'cr__icon-camera-outline']
# Potential container found: ['cr__asset__wrapper']
# Potential container found: ['iconWrapper', 'iconWrapper', 'cameraIcon', 'cr__icon-camera-outline']
# Potential container found: ['cr__asset__wrapper']
# Potential container found: ['iconWrapper', 'iconWrapper', 'cameraIcon', 'cr__icon-camera-outline']
# Potential container found: ['cr__asset__wrapper']
# Potential container found: ['iconWrapper', 'iconWrapper', 'cameraIcon', 'cr__icon-camera-outline']
# Potential container found: ['cr__asset__wrapper']
# Potential container found: ['iconWrapper', 'iconWrapper', 'cameraIcon', 'cr__icon-camera-outline']
# Potential container found: ['cr__asset__wrapper']
# Potential container found: ['slick-list', 'draggable']
# Potential container found: ['contentRender', 'contentRender_19', 'contentRender_type_panel', 'contentRender_name_plugins_common_container_intro']
# Potential container found: ['content-wrapper']
# Potential container found: ['read-more-wrapper']
# Potential container found: ['contentRender', 'contentRender_21', 'contentRender_type_widget', 'contentRender_name_plugins_events_layout_list']
# Potential container found: ['filterPane', 'stickyContainer']
# Potential container found: ['asd__wrapper', 'asd__wrapper--datepicker-open', 'asd__wrapper--inline']
# Potential container found: ['asd__inner-wrapper']
# Potential container found: ['layout-container']
# Potential container found: ['content-map-wrapper']
# Potential container found: ['slick-list', 'draggable']
# Potential container found: ['contentRender', 'contentRender_23', 'contentRender_type_panel', 'contentRender_name_plugins_common_container']
# Potential container found: ['panel-container']
# Potential container found: ['footer-container']
# Potential container found: ['translage-trip-wrapper']
# Potential container found: ['transition-container', 'transition-exited']
# Searching for content list with: {'div': {'class': 'content grid'}}
# Attempting to find content list by class: content grid
# Found 12 items with specified attributes
# Extracted 12 events
# Title: Chickamauga Dam Lock Through Kayak Tour with Chattanooga Guided Adventures
# URL: https://www.visitchattanooga.com/events//event/chickamauga-dam-lock-through-kayak-tour-with-chattanooga-guided-adventures/19807/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga

# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/Senior-Olympics-Logo_1F4B129D-CCB7-E02E-1F6207CCD2C903CC_1f89e8f2-f66d-d49c-2d194877b980f990.jpg
# Location: Chattanooga Convention Center
# Recurrence: Recurring daily until August 11, 2024
# ----------------------------------------
# Title: The Music Of Danimal and Friends
# URL: https://www.visitchattanooga.com/events//event/the-music-of-danimal-and-friends/20539/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/clients/chattanooga/chattanooga_default_170b93b4-2635-4fb3-84b2-7c68ad33306f.jpg
# Location: Comedy Catch at the Choo Choo and Backstage Bar
# Recurrence: Recurring weekly on Wednesday until April 9, 2025
# ----------------------------------------
# Title: Wine Down Wednesday
# URL: https://www.visitchattanooga.com/events//event/wine-down-wednesday/20965/
# Date: None
# Start Time: None
# End Time: None
# Image URL: https://assets.simpleviewinc.com/simpleview/image/upload/c_fill,h_227,q_75,w_340/v1/crm/chattanooga/24-WDW-Wine-Down-0351_0C0788B7-B974-4E94-85AF4D0AB2ED2EC3_32848495-dad0-4295-a749e741aecf18de.jpg
# Location: Frothy Monkey
# Recurrence: Recurring weekly on Wednesday
# ----------------------------------------
# Fetching and parsing CHA Guide Events
# Could not find 'grid' class in the HTML
# Length of parsed content: 356676
# Potential container found: ['standard-container']
# Potential container found: ['filter-container']
# Potential container found: ['flex-wrapper', 'w-row']
# Potential container found: ['listing-div']
# Potential container found: ['events---all']
# Potential container found: ['flex-wrapper', 'w-dyn-list']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['w-pagination-wrapper']
# Potential container found: ['events---major']
# Potential container found: ['flex-wrapper', 'w-dyn-list']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['w-pagination-wrapper']
# Potential container found: ['events---outdoors']
# Potential container found: ['flex-wrapper', 'w-dyn-list']
# Potential container found: ['w-pagination-wrapper']
# Potential container found: ['events---arts']
# Potential container found: ['flex-wrapper', 'w-dyn-list']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['w-pagination-wrapper']
# Potential container found: ['events---community']
# Potential container found: ['flex-wrapper', 'w-dyn-list']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['w-pagination-wrapper']
# Potential container found: ['events---business']
# Potential container found: ['flex-wrapper', 'w-dyn-list']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['flex-4-columns', 'events', 'w-dyn-item']
# Potential container found: ['w-pagination-wrapper']
# Searching for content list with: {'div': {'class': 'flex-table w-dyn-items'}}
# Attempting to find content list by class: flex-table w-dyn-items
# Found 76 items with specified attributes
# Extracted 76 events
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-44
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: AM Networking
# URL: https://www.cha.guide/events/events/am-networking
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: 2265 Gunbarrel Rd
# Recurrence:
# ----------------------------------------
# Title: Free Family Night @ Creative Discovery Museum
# URL: https://www.cha.guide/events/events/free-family-night-creative-discovery-museum-4
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Creative Discovery Museum
# Recurrence:
# ----------------------------------------
# Title: Open Mic Night (Summer Series!) @ Songbirds
# URL: https://www.cha.guide/events/events/open-mic-night-summer-series-songbirds-2
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Songbirds
# Recurrence:
# ----------------------------------------
# Title: Nightfall 2024
# URL: https://www.cha.guide/events/events/nightfall-2024-12
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Miller Plaza & Miller Park
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-18
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga River Market
# URL: https://www.cha.guide/events/events/chattanooga-river-market-40
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Aquarium Plaza
# Recurrence:
# ----------------------------------------
# Title: Chickamauga Turn
# URL: https://www.cha.guide/events/events/chickamauga-turn-17
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Riverfront Nights
# URL: https://www.cha.guide/events/events/riverfront-nights-12
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Ross’s Landing
# Recurrence:
# ----------------------------------------
# Title: EVENING RIDGE RUNNER
# URL: https://www.cha.guide/events/events/evening-ridge-runner-19
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Tennessee Valley Railroad Museum
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-45
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Art Deco And Dance With Ballet Esprit
# URL: https://www.cha.guide/events/events/art-deco-and-dance-with-ballet-esprit
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Hunter Museum of American Art
# Recurrence:
# ----------------------------------------
# Title: Business After Hours | Big Chicken
# URL: https://www.cha.guide/events/events/business-after-hours-big-chicken
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location:
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-59
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-60
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-61
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: Chattanooga Market at Erlanger
# URL: https://www.cha.guide/events/events/chattanooga-market-at-erlanger-62
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: Erlanger Medical Mall
# Recurrence:
# ----------------------------------------
# Title: WHITECHAPEL "TENNESSEE TAKEOVER 2024"
# URL: https://www.cha.guide/events/events/whitechapel-tennessee-takeover-2024
# Date: None
# Start Time: None
# End Time: None
# Image URL: None
# Location: The Signal
# Recurrence:
# ----------------------------------------
# Fetching and parsing Chattanooga Pulse
# Could not find 'grid' class in the HTML
# Length of parsed content: 116993
# Potential container found: ['mp-filterbar-container']
# Potential container found: ['numInputWrapper']
# Potential container found: ['flatpickr-innerContainer']
# Potential container found: ['flatpickr-rContainer']
# Potential container found: ['flatpickr-weekdaycontainer']
# Potential container found: ['dayContainer']
# Potential container found: ['numInputWrapper']
# Potential container found: ['flatpickr-innerContainer']
# Potential container found: ['flatpickr-rContainer']
# Potential container found: ['flatpickr-weekdaycontainer']
# Potential container found: ['dayContainer']
# Searching for content list with: {'div': {'id': 'event_list_div'}}
# Attempting to find content list by id: event_list_div
# Found 20 items with specified attributes
# Extracted 20 events
# Title: Joggers & Lagers
# URL:
# Date: 2024-08-06
# Start Time: 18:00
# End Time: 19:00
# Image URL: https://www.chattanoogapulse.com/downloads/16190/download/joggers%20%26%20lagers.png?cb=ccf918643a4c2d1a569ebfe82f3ddd7c&w=220&h=
# Location: Joggers & Lagers
# Recurrence: Outdoor, This & That
# ----------------------------------------
# Title: Paths to Pints along the Riverwalk
# URL:
# Date: 2024-08-06
# Start Time: 18:30
# End Time: None
# Image URL: https://www.chattanoogapulse.com/downloads/16001/download/Paths%20to%20Pints.png?cb=7f42636cc48cbabbf35f99d0f4b8e3ae&w=220&h=
# Location: Paths to Pints along the Riverwalk
# Recurrence: Food & Drink, Outdoor
# ----------------------------------------
# Title: Danimal And Friends
# URL:
# Date: 2024-08-06
# Start Time: 19:00
# End Time: 20:30
# Image URL: https://www.chattanoogapulse.com/downloads/16361/download/Danimal%20And%20Friends%202.png?cb=ef6c5023aa32382083cfe862b4bbe0ea&w=220&h=
# Location: Danimal And Friends
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Title: Introduction to Calm Abiding Meditation
# URL:
# Date: 2024-08-06
# Start Time: 19:00
# End Time: 20:30
# Image URL: https://www.chattanoogapulse.com/downloads/29818/download/IMG_2882.jpeg?cb=b0051075fdfe7f7f4641797a5610fde5&w=220&h=
# Location: Introduction to Calm Abiding Meditation
# Recurrence: Education & Learning, Health & Wellness
# ----------------------------------------
# Title: Main Street Farmers Market
# URL:
# Date: 2024-08-07
# Start Time: 16:00
# End Time: 18:00
# Image URL: https://www.chattanoogapulse.com/downloads/15605/download/main%20street%20market%20new.png?cb=ae85f55f8c57352275b7718935c83aef&w=220&h=
# Location: Main Street Farmers Market
# Recurrence: Markets
# ----------------------------------------
# Title: Teni Rane 'Goldenrod' Album Release Celebration
# URL:
# Date: 2024-08-07
# Start Time: 18:00
# End Time: 20:00
# Image URL: https://www.chattanoogapulse.com/downloads/30574/download/Teni-Rane-Goldenrod-Album-Release-Show-Yellow-Racket-Records-August-7-2024.jpg?cb=13f3f2ed9f4b4c175f91f9fbf581e4c0&w=220&h=
# Location: Teni Rane 'Goldenrod' Album Release Celebration
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Title:
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Title: Live Music with Jason Lyles
# URL:
# Date: 2024-08-08
# Start Time: 18:30
# End Time: 20:30
# Image URL: https://www.chattanoogapulse.com/downloads/29175/download/jason%20lyles%201.png?cb=ad03a36ca35ab03d03c646e57c7dda91&w=220&h=
# Location: Live Music with Jason Lyles
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Title: Improv
# URL:
# Date: 2024-08-08
# Start Time: 19:00
# End Time: 21:00
# Image URL: https://www.chattanoogapulse.com/downloads/23786/download/Improv.JPG?cb=d8280c5ace2c9c6314e50237ade2111d&w=220&h=
# Location: Improv
# Recurrence: Comedy, Concerts & Live Music, Food & Drink
# ----------------------------------------
# Title: Open Mic Night
# URL:
# Date: 2024-08-08
# Start Time: 19:00
# End Time: 21:00
# Image URL: https://www.chattanoogapulse.com/downloads/30279/download/Open%20Mic%20Banner.jpg?cb=57b83bbdb8e0336b0b93ebe68ad4de7c&w=220&h=
# Location: Open Mic Night
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Title: Toby Hewitt
# URL:
# Date: 2024-08-08
# Start Time: 19:00
# End Time: 22:00
# Image URL: https://www.chattanoogapulse.com/downloads/16348/download/Toby%20Hewitt.png?cb=26151dee680a07f9e0f0c4e7be42de3f&w=220&h=
# Location: Toby Hewitt
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Title: Cinderella's Tom Keifer With Special Guests L.A. Guns
# URL:
# Date: 2024-08-08
# Start Time: 20:00
# End Time: 23:59
# Image URL: https://www.chattanoogapulse.com/downloads/29616/download/71655.jpg?cb=f47cac615efa0ed3d00dd9b1b3e2930e&w=220&h=
# Location: Cinderella's Tom Keifer With Special Guests L.A. Guns
# Recurrence: Concerts & Live Music
# ----------------------------------------
# Fetching and parsing Times Free Press
# Found Shadow DOM host: div, id: evvnt-calendar
# Could not find 'grid' class in the HTML
# Length of parsed content: 145462
# Potential container found: ['header__nav__menu', '|', 'wrapper']
# Searching for content list with: {'div': {'class': 'grid'}}
# Attempting to find content list by class: grid
# Attempting to find content list by tag: div
# Found 0 items with specified attributes
# Extracted 0 events

# %% [markdown]
# # DIFFERENT EXTRACTION TECHNIQUE
#
# ## IS CURRENTLY PAGE SPECIFIC

# %%
from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import chromedriver_autoinstaller
from bs4 import BeautifulSoup
from datetime import datetime
from dateutil import parser
import time
import re

# Configuration
SITES = {

    "Visit Chattanooga": {
        "url": "https://www.visitchattanooga.com/events/",
        "content_list_class": {"div": {"class": "content grid"}},
        "item_attr": {"div": {"data-type": "events"}},
        "title": {"a": {"class": "title truncate"}},
        "date": {"span": {"class": "mini-date-container"}}, # now broken since dateutil. Check for start and end times
        "img": { # Need to display as image
            "img": {"class": "thumb"},
            "parse_method": "lazy-src"
        },
        "location": {"li": {"class": "locations truncate"}},
        "recurrence": {"li": {"class": "recurrence"}}
    },

    "CHA Guide Events": {
        "url": "https://www.cha.guide/events",
        "content_list_class": {"div": {"class": "flex-table w-dyn-items"}},
        "item_attr": {"div": {"role": "listitem"}},
        "title": {"h3": {"class": "event-title"}},
        "date": {"div": {"class": "event-date-div"}}, # now broken since dateutil. Check for start and end times
        "img": {
            "parse_method": "none",
        },
        "location": {"div": {"class": "location-2"}},
        "recurrence": {"div": {"class": "event---category-circle"}},
        # "category": {"div": {"class": "event---category-circle"}},
        # "details": {"div": {"class": "smaller-text bottom-margin---5px"}}
    },
    
    "Chattanooga Pulse": {
        "url": "https://www.chattanoogapulse.com/search/event/the-pulse-event-search/#page=1", # no event url
        "content_list_class": {"div": {"id": "event_list_div"}},
        "item_attr": {"div": {"class": "event_result"}},
        "title": {"h4": {"class": "event_title"}},
        "date": {"p": {"class": "event_date"}}, # need to format as AM/PM
        "img": { # Need to display as image
            "container": {"div": {"class": "event_thumb"}},
            "tag": "img",
            "attr": "srcset",
            "parse_method": "srcset_220w"
        },
        "location": {"a": {}}, # outputs title instead of location
        "recurrence": {"p": {"class": "cats"}},
        # "details": {"div": {"class": "smaller-text bottom-margin---5px"}}
        

    },
    
    # "Nooga Today": {
    #     "url": "https://noogatoday.6amcity.com/events#/", # preloaded_lightbox blocking site
    #     },
    
    # "Choose Chatt": {
    #     "url": "https://choosechatt.com/chattanooga-events/", # dialog-lightbox-message blocking site
    # },

    "Times Free Press": {
        "url": "https://www.timesfreepress.com/tfpevents/?_evDiscoveryPath=/",
        "content_list_class": {"div": {"class": "grid"}},
        "item_attr": {"div": {"class": "c-card"}},
        "title": {"h3": {}},
        "date": {"div": {"class": "rounded-r"}},
        "img": {
            "img": {"class": "event-image"},
            "parse_method": "src"
        },
        "location": {"li": {"class": "line-clamp-1"}},
        "recurrence": None,  # No clear recurrence information in the provided HTML
        "time": {"li": {"class": None}},  # The first <li> element contains the time
        "price": {"li": None}  # The last <li> element contains the price
    },

    # "CHA Guide Weekly": {
    #     "url": "https://www.cha.guide/explore/things-to-do-in-chattanooga-this-week",
    # },

    # "Chattanooga Chamber": {
    #     "url": "https://chattanoogachamber.com/",
    # },

    # "Chattanooga Library": {
    #     "url": "https://www.chattlibrary.org/events/",
    # }

}

def fetch_page(url):
    # options = Options()
    # options.add_argument("--headless")  # Run in headless mode (no GUI)
    # service = Service(ChromeDriverManager().install())
    chromedriver_autoinstaller.install()
    driver = webdriver.Chrome()
    
    try:
        driver.get(url)
        time.sleep(5)  # Wait for JavaScript to load content
        return driver.page_source
    except Exception as e:
        print(f"Error fetching the page: {e}")
        return None
    finally:
        driver.quit()

def parse_html(html_content):
    return BeautifulSoup(html_content, 'html.parser')

def extract_image_url(img_config, item):
    if img_config['parse_method'] == 'lazy-src':
        img_tag, img_attrs = next(iter(img_config.items()))
        img_element = item.find(img_tag, **img_attrs)
        return img_element.get('data-lazy-src') or img_element.get('src') if img_element else None

    elif img_config['parse_method'] == 'srcset_220w':
        container_tag, container_attrs = next(iter(img_config['container'].items()))
        container = item.find(container_tag, **container_attrs)
        if not container:
            return None

        img_element = container.find(img_config['tag'])
        if not img_element or img_config['attr'] not in img_element.attrs:
            return None

        srcset = img_element[img_config['attr']]
        urls = srcset.split(', ')
        for url in urls:
            if '220w' in url:
                return url.split(' ')[0]
        return urls[0].split(' ')[0] if urls else None

    elif img_config['parse_method'] == 'none':
        return None
    
    # Add other parsing methods here if needed
    
    return None

def parse_date_range(date_text):
    # Regular expression to match date, start time, and end time
    pattern = r'(\w+ \d+, \d{4})(?: (\d+:\d+ [AP]M))?(?: - (\d+:\d+ [AP]M))?'
    match = re.match(pattern, date_text)
    
    if match:
        date_str, start_time, end_time = match.groups()
        
        try:
            # Parse the date
            parsed_date = parser.parse(date_str)
            date = parsed_date.strftime("%Y-%m-%d")
            
            # Parse start time if available
            start = None
            if start_time:
                start = parser.parse(f"{date_str} {start_time}").strftime("%H:%M")
            
            # Parse end time if available
            end = None
            if end_time:
                end = parser.parse(f"{date_str} {end_time}").strftime("%H:%M")
            
            return {
                'date': date,
                'start_time': start,
                'end_time': end
            }
        except ValueError:
            print(f"Couldn't parse date: {date_text}")
    
    return {
        'date': None,
        'start_time': None,
        'end_time': None
    }

# TODO: category function

# TODO: details function

def extract_events(parsed_content, config):
    events = []
    
    # Find all div elements that might be event cards
    potential_events = parsed_content.find_all('div', class_=lambda x: x and 'card' in x.lower())
    
    for item in potential_events:
        event = {}
        
        # Extract title
        title_element = item.find('h3')
        if title_element:
            event['title'] = title_element.text.strip()
        
        # Extract date
        date_element = item.find('div', class_=lambda x: x and 'rounded-r' in x)
        if date_element:
            event['date'] = date_element.text.strip()
        
        # Extract image URL
        img_element = item.find('img', class_='event-image')
        if img_element and 'src' in img_element.attrs:
            event['image_url'] = img_element['src']
        
        # Extract location, time, and price
        list_items = item.find_all('li')
        if len(list_items) >= 3:
            event['time'] = list_items[0].text.strip()
            event['location'] = list_items[1].text.strip()
            event['price'] = list_items[-1].text.strip()
        
        if event:  # Only append if we found some information
            events.append(event)
    
    return events

def main():
    for site_name, config in SITES.items():
        url = config["url"]
        print(f"Fetching and parsing {site_name}")

        html_content = fetch_page(url)
        if html_content:
            grid_match = re.search(r'<div[^>]*class="[^"]*grid[^"]*"', html_content)#
            if grid_match:#
                start = max(0, grid_match.start() - 500)#
                end = min(len(html_content), grid_match.end() + 1000)#
                print(html_content[start:end])#
            else:#
                print("Could not find 'grid' class in the HTML")#
            parsed_content = parse_html(html_content)
            print(f"Length of parsed content: {len(str(parsed_content))}")
            iframes = parsed_content.find_all('iframe')
            for iframe in iframes:
                print(f"Found iframe: {iframe.get('src', 'No src attribute')}")
            events = extract_events(parsed_content, config)
            print(f"Extracted {len(events)} events")
            for event in events:
                print(f"Title: {event.get('title')}")
                print(f"URL: {event.get('url')}")
                print(f"Date: {event.get('date')}")
                print(f"Start Time: {event.get('start_time')}")
                print(f"End Time: {event.get('end_time')}")
                print(f"Image URL: {event.get('image_url')}")
                print(f"Location: {event.get('location')}")
                print(f"Recurrence: {event.get('recurrence')}")
                print("-" * 40)
        else:
            print(f"Skipping {site_name} due to fetch error")
        time.sleep(1)  # Be polite, wait a second between requests

if __name__ == "__main__":
    main()



####################
# BUGS & TODOS
####################


# TODO: category function

# TODO: details function

# BUG: rewrite date function to work on all sites (output times as AM/PM)

# TODO: add a time and price function (time could be included in date function)

# TODO: pull individual functions out of extract_events

# TODO: display image link as an image instead of a url

# BUG: fix event url and location in pulse
# Out:
# Fetching and parsing Visit Chattanooga
# entRender_type_widget contentRender_name_plugins_common_embed" data-sv-time="48" data-sv-index="16" data-gtm-vars="{ &quot;tCore&quot; : { &quot;contentNum&quot; : &quot;1&quot; } }"><div class="custom-embed" data-guid="8cac3647-74d0-4c7a-a6be-61ae51cfd005">
#     <script id="cr-init__a35f8e0291db91cd" src="https://starling.crowdriff.com/js/crowdriff.js" async=""></script><div id="cr__a35f8e0291db91cd"><div id="cr__app" class="cr__gallery cr__gallery__isGalleryRefresh" style="overflow-x: hidden;"><div class="cr__grid clearfix" id="a35f8e0291db91cd" style="margin: 0px -2.5px; padding-top: 2.5px; padding-bottom: 2.5px; position: relative;"><div class="erd_scroll_detection_container erd_scroll_detection_container_animation_active" style="visibility: hidden; display: inline; width: 0px; height: 0px; z-index: -1; overflow: hidden; margin: 0px; padding: 0px;"><div dir="ltr" class="erd_scroll_detection_container" style="position: absolute; flex: 0 0 auto; overflow: hidden; z-index: -1; visibility: hidden; width: 100%; height: 100%; left: 0px; top: 0px;"><div class="erd_scroll_detection_container" style="position: absolute; flex: 0 0 auto; overflow: hidden; z-index: -1; visibility: hidden; inset: -16px -15px -15px -16px;"><div style="position: absolute; flex: 0 0 auto; overflow: scroll; z-index: -1; visibility: hidden; width: 100%; height: 100%;"><div style="position: absolute; left: 0px; top: 0px; width: 1659px; height: 318px;"></div></div><div style="position: absolute; flex: 0 0 auto; overflow: scroll; z-index:
# Length of parsed content: 505042
# Found iframe: //www.googletagmanager.com/ns.html?id=GTM-MQX2GG
# Found iframe: //www.googletagmanager.com/ns.html?id=GTM-NFBVG93
# Found iframe: javascript:false
# Found iframe: //20832837p.rfihub.com/ca.html?rb=44011&ca=20832837&_o=44011&_t=20832837&ra=669463689
# Found iframe: //20832838p.rfihub.com/ca.html?rb=44011&ca=20832838&_o=44011&_t=20832838&ra=963796291
# Found iframe: https://6447211.fls.doubleclick.net/activityi;src=6447211;type=homep0;cat=dcmfl00;ord=6872659459638;npa=0;auiddc=26985509.1723122381;ps=1;pcor=193529150;uaa=x86;uab=64;uafvl=Not)A%253BBrand%3B99.0.0.0%7CGoogle%2520Chrome%3B127.0.6533.99%7CChromium%3B127.0.6533.99;uamb=0;uam=;uap=Linux;uapv=6.8.0;uaw=0;pscdl=noapi;frm=0;gtm=45fe4851v9189051306z871860688za201zb71860688;gcd=13l3l3l3l1;dma=0;tag_exp=0;epver=2;~oref=https%3A%2F%2Fwww.visitchattanooga.com%2Fevents%2F?
# Found iframe: https://9715013.fls.doubleclick.net/activityi;src=9715013;type=universa;cat=unive0;ord=6264820376442;npa=0;auiddc=26985509.1723122381;ps=1;pcor=509035443;uaa=x86;uab=64;uafvl=Not)A%253BBrand%3B99.0.0.0%7CGoogle%2520Chrome%3B127.0.6533.99%7CChromium%3B127.0.6533.99;uamb=0;uam=;uap=Linux;uapv=6.8.0;uaw=0;pscdl=noapi;frm=0;gtm=45fe4851v9189896283z871860688za201zb71860688;gcd=13l3l3l3l1;dma=0;tag_exp=0;epver=2;~oref=https%3A%2F%2Fwww.visitchattanooga.com%2Fevents%2F?
# Found iframe: javascript:false
# Found iframe: https://wsv3cdn.audioeye.com/v2/frame/cookieStorage.html?build=prod/m&pscb=&cb=3358eb1
# Extracted 0 events
# Fetching and parsing CHA Guide Events
# Could not find 'grid' class in the HTML
# Length of parsed content: 350744
# Extracted 0 events
# Fetching and parsing Chattanooga Pulse
# Could not find 'grid' class in the HTML
# Length of parsed content: 93880
# Found iframe: https://www.googletagmanager.com/ns.html?id=GTM-WL6W234
# Found iframe: No src attribute
# Found iframe: No src attribute
# Found iframe: No src attribute
# Found iframe: No src attribute
# Found iframe: No src attribute
# Found iframe: No src attribute
# Found iframe: https://www.google.com/recaptcha/api2/aframe
# Found iframe: https://securepubads.g.doubleclick.net/static/topics/topics_frame.html
# Extracted 0 events
# Fetching and parsing Times Free Press
# Could not find 'grid' class in the HTML
# Length of parsed content: 142354
# Found iframe: https://www.googletagmanager.com/ns.html?id=GTM-PLGJB35>m_auth=crXwMCzm9bfw_0aqgGSH_g>m_preview=env-1>m_cookies_win=x
# Found iframe: https://www.googletagmanager.com/ns.html?id=GTM-NLLP6W
# Found iframe: No src attribute
# Found iframe: about:blank
# Found iframe: No src attribute
# Found iframe: No src attribute
# Found iframe: about:blank
# Found iframe: about:blank
# Found iframe: about:blank
# Found iframe: about:blank
# Found iframe: about:blank
# Found iframe: https://s.amazon-adsystem.com/iu3?cm3ppd=1&d=dtb-pub&csif=t&dl=n-sharethrough_n-adMediaV1_pm-db5_n-simpli.fi_rbd_n-baidu_an-db5_sovrn_3lift
# Found iframe: No src attribute
# Found iframe: https://insight.adsrvr.org/track/up?adv=imws764&ref=https%3A%2F%2Fwww.timesfreepress.com%2Ftfpevents%2F%3F_evDiscoveryPath%3D%2F&upid=mw88qe2&upv=1.1.0&gdpr=0&gdpr_consent=undefined
# Found iframe: https://www.google.com/recaptcha/api2/aframe
# Found iframe: https://securepubads.g.doubleclick.net/static/topics/topics_frame.html
# Found iframe: https://acdn.adnxs.com/dmp/async_usersync.html
# Found iframe: https://ads.pubmatic.com/AdServer/js/user_sync.html?kdntuid=1&p=158314
# Found iframe: https://eus.rubiconproject.com/usync.html
# Found iframe: https://gum.criteo.com/syncframe?origin=criteoPrebidAdapter&topUrl=www.timesfreepress.com&gpp=#{%22cw%22:true,%22lsw%22:true,%22origin%22:%22criteoPrebidAdapter%22,%22requestId%22:%220.9602355789493988%22,%22tld%22:%22www.timesfreepress.com%22,%22topUrl%22:%22www.timesfreepress.com%22,%22version%22:%229_4_1%22}
# Found iframe: https://ads.yieldmo.com/pbcas?us_privacy=&gdpr=0&gdpr_consent=&type=iframe
# Found iframe: https://eb2.3lift.com/sync?
# Found iframe: https://sync.richaudience.com/dcf3528a0b8aa83634892d50e91c306e/?ord=1378770042
# Found iframe: https://ascendeum-d.openx.net/w/1.0/pd
# Extracted 0 events
